# %%
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

fox = "https://cctigers.com/sports/mens-basketball/stats/2022-2023/george-fox-university/boxscore/8903"
braska = "https://cctigers.com/sports/mens-basketball/stats/2022-2023/nebraska-wesleyan-university/boxscore/8905"

driver.get(fox)
soup_fox = BeautifulSoup(driver.page_source, 'html.parser')
driver.get(braska)
soup_braska = BeautifulSoup(driver.page_source, 'html.parser')

driver.quit()
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 109.0.5414
# [WDM] - Get LATEST chromedriver version for 109.0.5414 google-chrome
# [WDM] - Driver [/Users/jeremydumalig/.wdm/drivers/chromedriver/mac64/109.0.5414.74/chromedriver] found in cache
# /var/folders/91/7lxj2xq13852sql471wdl0pw0000gn/T/ipykernel_29136/3167238115.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
half1 = soup_fox.find_all('table', {'class' : 'sidearm-table play-by-play'})[0]
half2 = soup_fox.find_all('table', {'class' : 'sidearm-table play-by-play'})[1]
half3 = soup_braska.find_all('table', {'class' : 'sidearm-table play-by-play'})[0]
half4 = soup_braska.find_all('table', {'class' : 'sidearm-table play-by-play'})[1]

# %%
def action_team_fox(action):
    if "by" in [i.text for i in action][0]:
        return 'Opponent'
    else:
        return 'Colorado'
    
def action_team_braska(action):
    if "by" in [i.text for i in action][0]:
        return 'Colorado'
    else:
        return 'Opponent'

# %%
def soup_to_df(half, opp):
    times = [i.find('td').text for i in half.find_all('tr')[1:]]

    raw_actions = [i.find_all('td', {'class' : 'hide-on-medium-down'}) for i in half.find_all('tr')[1:]]
    actions = [[i.text for i in action if 'by' in i.text][0] for action in raw_actions]

    if opp == 'Fox':
        teams = [action_team_fox(a) for a in raw_actions]
    else:
        teams = [action_team_braska(a) for a in raw_actions]

    game = pd.DataFrame({'Time' : ["20:00"] + times, 
                         'Action' : ["TIP by "] + actions, 
                         'Team' : [teams[0]] + teams})
    
    game['Action'] = game['Action'].apply(lambda s : s.split(" by ")[0])
    
    return game

df1 = soup_to_df(half1, 'Fox')
df2 = soup_to_df(half2, 'Fox')
df3 = soup_to_df(half3, 'Braska')
df4 = soup_to_df(half4, 'Braska')

# %%
soup_to_df(half1, 'Fox')
# Out:
#       Time         Action      Team
# 0    20:00            TIP  Opponent
# 1    19:48    MISS JUMPER  Opponent
# 2       --    REBOUND DEF  Colorado
# 3    19:22    GOOD JUMPER  Colorado
# 4    19:11      MISS 3PTR  Opponent
# 5       --    REBOUND DEF  Colorado
# 6    18:51          FOUL   Opponent
# 7    18:41      TURNOVER   Colorado
# 8    18:41         STEAL   Opponent
# 9    18:35    MISS JUMPER  Opponent
# 10   18:35         BLOCK   Colorado
# 11      --    REBOUND OFF  Opponent
# 12   18:28     MISS LAYUP  Opponent
# 13      --    REBOUND DEF  Colorado
# 14   18:28      TURNOVER   Colorado
# 15   18:28        SUB OUT  Colorado
# 16   18:28         SUB IN  Colorado
# 17   18:20      MISS 3PTR  Opponent
# 18      --    REBOUND DEF  Colorado
# 19   18:11          FOUL   Opponent
# 20   18:11        SUB OUT  Colorado
# 21   18:11         SUB IN  Colorado
# 22   18:10      MISS 3PTR  Colorado
# 23      --    REBOUND DEF  Opponent
# 24   17:51    MISS JUMPER  Opponent
# 25      --    REBOUND DEF  Colorado
# 26   17:43      MISS 3PTR  Colorado
# 27      --    REBOUND DEF  Opponent
# 28   17:20      MISS 3PTR  Opponent
# 29      --    REBOUND DEF  Colorado
# 30   17:11      TURNOVER   Colorado
# 31   17:11        SUB OUT  Opponent
# 32   17:11         SUB IN  Opponent
# 33   17:11        SUB OUT  Colorado
# 34   17:11         SUB IN  Colorado
# 35   17:01     MISS LAYUP  Opponent
# 36   17:01         BLOCK   Colorado
# 37      --    REBOUND DEF  Colorado
# 38   16:53      GOOD DUNK  Colorado
# 39      --        ASSIST   Colorado
# 40   16:39      MISS 3PTR  Opponent
# 41      --    REBOUND DEF  Colorado
# 42   16:23    MISS JUMPER  Colorado
# 43      --    REBOUND DEF  Opponent
# 44   16:15      GOOD 3PTR  Opponent
# 45      --        ASSIST   Opponent
# 46   16:03          FOUL   Opponent
# 47   16:03        SUB OUT  Colorado
# 48   16:03        SUB OUT  Colorado
# 49   16:03         SUB IN  Colorado
# 50   16:03         SUB IN  Colorado
# 51   16:03        SUB OUT  Opponent
# 52   16:03        SUB OUT  Opponent
# 53   16:03        SUB OUT  Opponent
# 54   16:03         SUB IN  Opponent
# 55   16:03         SUB IN  Opponent
# 56   16:03         SUB IN  Opponent
# 57   15:56      TURNOVER   Colorado
# 58   15:56  TIMEOUT MEDIA  Opponent
# 59   15:56        SUB OUT  Opponent
# 60   15:56         SUB IN  Opponent
# 61   15:43          FOUL   Colorado
# 62   15:43        MISS FT  Opponent
# 63      --  REBOUND DEADB  Opponent
# 64   15:43        MISS FT  Opponent
# 65      --    REBOUND OFF  Opponent
# 66   15:36    GOOD JUMPER  Opponent
# 67   15:24     MISS LAYUP  Colorado
# 68      --    REBOUND DEF  Opponent
# 69   15:17      MISS 3PTR  Opponent
# 70   15:14        SUB OUT  Colorado
# 71   15:14        SUB OUT  Colorado
# 72   15:14         SUB IN  Colorado
# 73   15:14         SUB IN  Colorado
# 74      --    REBOUND OFF  Opponent
# 75   15:04    MISS JUMPER  Opponent
# 76      --    REBOUND OFF  Opponent
# 77   14:54      GOOD 3PTR  Opponent
# 78      --        ASSIST   Opponent
# 79   14:23     GOOD LAYUP  Colorado
# 80      --        ASSIST   Colorado
# 81   14:13      MISS 3PTR  Opponent
# 82      --    REBOUND DEF  Colorado
# 83   14:04      TURNOVER   Colorado
# 84   14:04         STEAL   Opponent
# 85   13:58     MISS LAYUP  Opponent
# 86      --    REBOUND OFF  Opponent
# 87   13:58         BLOCK   Colorado
# 88   13:52     GOOD LAYUP  Opponent
# 89   13:51  TIMEOUT 30SEC  Opponent
# 90   13:51        SUB OUT  Opponent
# 91   13:51        SUB OUT  Opponent
# 92   13:51        SUB OUT  Opponent
# 93   13:51         SUB IN  Opponent
# 94   13:51         SUB IN  Opponent
# 95   13:51         SUB IN  Opponent
# 96   13:39      TURNOVER   Colorado
# 97   13:39         STEAL   Opponent
# 98   13:39        SUB OUT  Colorado
# 99   13:39         SUB IN  Colorado
# 100  13:30      TURNOVER   Opponent
# 101  13:22          FOUL   Opponent
# 102  13:04    MISS JUMPER  Colorado
# 103     --    REBOUND DEF  Opponent
# 104  12:56      TURNOVER   Opponent
# 105  12:56         STEAL   Colorado
# 106  12:51          FOUL   Opponent
# 107  12:51        SUB OUT  Opponent
# 108  12:51        SUB OUT  Opponent
# 109  12:51         SUB IN  Opponent
# 110  12:51         SUB IN  Opponent
# 111  12:42    MISS JUMPER  Colorado
# 112     --    REBOUND DEF  Opponent
# 113  12:31    GOOD JUMPER  Opponent
# 114  12:05      TURNOVER   Colorado
# 115  11:50      MISS 3PTR  Opponent
# 116     --    REBOUND DEF  Colorado
# 117  11:38    GOOD JUMPER  Colorado
# 118     --        ASSIST   Colorado
# 119  11:30    MISS JUMPER  Opponent
# 120  11:30         BLOCK   Colorado
# 121     --    REBOUND DEF  Colorado
# 122  11:21          FOUL   Opponent
# 123  11:21  TIMEOUT MEDIA  Opponent
# 124  11:21        SUB OUT  Colorado
# 125  11:21         SUB IN  Colorado
# 126  11:21        SUB OUT  Opponent
# 127  11:21         SUB IN  Opponent
# 128  11:21        GOOD FT  Colorado
# 129  11:21        GOOD FT  Colorado
# 130  11:06      MISS 3PTR  Opponent
# 131  11:04        SUB OUT  Colorado
# 132  11:04         SUB IN  Colorado
# 133     --    REBOUND DEF  Colorado
# 134  10:46      TURNOVER   Colorado
# 135  10:46        SUB OUT  Opponent
# 136  10:46         SUB IN  Opponent
# 137  10:22      TURNOVER   Opponent
# 138  10:22        SUB OUT  Opponent
# 139  10:22        SUB OUT  Opponent
# 140  10:22         SUB IN  Opponent
# 141  10:22         SUB IN  Opponent
# 142  10:04     GOOD LAYUP  Colorado
# 143     --        ASSIST   Colorado
# 144  09:51    GOOD JUMPER  Opponent
# 145  09:30    MISS JUMPER  Colorado
# 146     --    REBOUND DEF  Opponent
# 147  09:29          FOUL   Colorado
# 148  09:12      MISS 3PTR  Opponent
# 149     --    REBOUND DEF  Colorado
# 150  09:02    MISS JUMPER  Colorado
# 151     --    REBOUND DEF  Opponent
# 152  08:52     MISS LAYUP  Opponent
# 153  08:52         BLOCK   Colorado
# 154     --    REBOUND DEF  Colorado
# 155  08:46          FOUL   Opponent
# 156  08:46        SUB OUT  Opponent
# 157  08:46        SUB OUT  Opponent
# 158  08:46         SUB IN  Opponent
# 159  08:46         SUB IN  Opponent
# 160  08:46        GOOD FT  Colorado
# 161  08:46        MISS FT  Colorado
# 162     --    REBOUND DEF  Opponent
# 163  08:34    MISS JUMPER  Opponent
# 164     --    REBOUND DEF  Colorado
# 165  08:29     MISS LAYUP  Colorado
# 166     --    REBOUND OFF  Colorado
# 167  08:26          FOUL   Opponent
# 168  08:26        GOOD FT  Colorado
# 169  08:26        SUB OUT  Colorado
# 170  08:26         SUB IN  Colorado
# 171  08:26        MISS FT  Colorado
# 172     --    REBOUND DEF  Opponent
# 173  08:25          FOUL   Colorado
# 174  08:25        SUB OUT  Colorado
# 175  08:25         SUB IN  Colorado
# 176  08:12          FOUL   Colorado
# 177  08:12        GOOD FT  Opponent
# 178  08:12        MISS FT  Opponent
# 179     --  REBOUND DEADB  Opponent
# 180  08:12        SUB OUT  Opponent
# 181  08:12         SUB IN  Opponent
# 182  08:12        GOOD FT  Opponent
# 183  07:58      TURNOVER   Colorado
# 184  07:58         STEAL   Opponent
# 185  07:52      MISS 3PTR  Opponent
# 186     --    REBOUND DEF  Colorado
# 187  07:44  TIMEOUT MEDIA  Opponent
# 188  07:44        SUB OUT  Colorado
# 189  07:44         SUB IN  Colorado
# 190  07:44        SUB OUT  Opponent
# 191  07:44         SUB IN  Opponent
# 192  07:44    MISS JUMPER  Colorado
# 193     --    REBOUND OFF  Colorado
# 194  07:44          FOUL   Opponent
# 195  07:44        MISS FT  Colorado
# 196     --    REBOUND DEF  Opponent
# 197  07:44          FOUL   Colorado
# 198  07:36      TURNOVER   Opponent
# 199  07:36         STEAL   Colorado
# 200  07:32     GOOD LAYUP  Colorado
# 201  07:23    MISS JUMPER  Opponent
# 202     --    REBOUND DEF  Colorado
# 203  06:58      GOOD 3PTR  Colorado
# 204     --        ASSIST   Colorado
# 205  06:43      MISS 3PTR  Opponent
# 206     --    REBOUND DEF  Colorado
# 207  06:31      MISS 3PTR  Colorado
# 208     --    REBOUND DEF  Opponent
# 209  06:28          FOUL   Colorado
# 210  06:28        SUB OUT  Colorado
# 211  06:28        SUB OUT  Colorado
# 212  06:28         SUB IN  Colorado
# 213  06:28         SUB IN  Colorado
# 214  06:28        SUB OUT  Opponent
# 215  06:28        SUB OUT  Opponent
# 216  06:28         SUB IN  Opponent
# 217  06:28         SUB IN  Opponent
# 218  06:13      MISS 3PTR  Opponent
# 219     --    REBOUND DEF  Colorado
# 220  05:45    MISS JUMPER  Colorado
# 221     --    REBOUND DEF  Opponent
# 222  05:39          FOUL   Colorado
# 223  05:39        GOOD FT  Opponent
# 224  05:39        SUB OUT  Colorado
# 225  05:39         SUB IN  Colorado
# 226  05:39        GOOD FT  Opponent
# 227  05:22     GOOD LAYUP  Colorado
# 228     --        ASSIST   Colorado
# 229  05:06      MISS 3PTR  Opponent
# 230     --    REBOUND DEF  Colorado
# 231  05:02          FOUL   Opponent
# 232  05:02        GOOD FT  Colorado
# 233  05:02        SUB OUT  Opponent
# 234  05:02        SUB OUT  Opponent
# 235  05:02         SUB IN  Opponent
# 236  05:02         SUB IN  Opponent
# 237  05:02        MISS FT  Colorado
# 238     --    REBOUND DEF  Opponent
# 239  04:51    MISS JUMPER  Opponent
# 240     --    REBOUND DEF  Colorado
# 241  04:29      TURNOVER   Colorado
# 242  04:29         STEAL   Opponent
# 243  04:24     MISS LAYUP  Opponent
# 244     --    REBOUND DEF  Colorado
# 245  04:18      TURNOVER   Colorado
# 246  04:18        SUB OUT  Colorado
# 247  04:18         SUB IN  Colorado
# 248  04:18        SUB OUT  Opponent
# 249  04:18        SUB OUT  Opponent
# 250  04:18         SUB IN  Opponent
# 251  04:18         SUB IN  Opponent
# 252  04:10      TURNOVER   Opponent
# 253  04:10         STEAL   Colorado
# 254  03:52    GOOD JUMPER  Colorado
# 255  03:33          FOUL   Colorado
# 256  03:33  TIMEOUT MEDIA  Opponent
# 257  03:33        SUB OUT  Colorado
# 258  03:33        SUB OUT  Colorado
# 259  03:33         SUB IN  Colorado
# 260  03:33         SUB IN  Colorado
# 261  03:33        GOOD FT  Opponent
# 262  03:33        GOOD FT  Opponent
# 263  03:10    GOOD JUMPER  Colorado
# 264     --        ASSIST   Colorado
# 265  03:00          FOUL   Colorado
# 266  03:00        SUB OUT  Opponent
# 267  03:00        SUB OUT  Opponent
# 268  03:00         SUB IN  Opponent
# 269  03:00         SUB IN  Opponent
# 270  03:00        GOOD FT  Opponent
# 271  03:00        MISS FT  Opponent
# 272     --    REBOUND DEF  Colorado
# 273  02:46    MISS JUMPER  Colorado
# 274     --    REBOUND DEF  Opponent
# 275  02:31     GOOD LAYUP  Opponent
# 276     --        ASSIST   Opponent
# 277  02:06      MISS 3PTR  Colorado
# 278     --    REBOUND DEF  Opponent
# 279  01:55      MISS 3PTR  Opponent
# 280     --    REBOUND DEF  Colorado
# 281  01:47      MISS 3PTR  Colorado
# 282     --    REBOUND DEF  Opponent
# 283  01:42          FOUL   Colorado
# 284  01:42        MISS FT  Opponent
# 285     --  REBOUND DEADB  Opponent
# 286  01:42        SUB OUT  Colorado
# 287  01:42        SUB OUT  Colorado
# 288  01:42         SUB IN  Colorado
# 289  01:42         SUB IN  Colorado
# 290  01:42        SUB OUT  Opponent
# 291  01:42        SUB OUT  Opponent
# 292  01:42         SUB IN  Opponent
# 293  01:42         SUB IN  Opponent
# 294  01:42        SUB OUT  Colorado
# 295  01:42         SUB IN  Colorado
# 296  01:42        MISS FT  Opponent
# 297     --    REBOUND DEF  Colorado
# 298  01:27    MISS JUMPER  Colorado
# 299  01:27         BLOCK   Opponent
# 300     --    REBOUND DEF  Opponent
# 301  00:59    GOOD JUMPER  Opponent
# 302  00:42    GOOD JUMPER  Colorado
# 303  00:41  TIMEOUT 30SEC  Opponent
# 304  00:41        SUB OUT  Opponent
# 305  00:41         SUB IN  Opponent
# 306  00:31      TURNOVER   Opponent
# 307  00:31         STEAL   Colorado
# 308  00:23    MISS JUMPER  Colorado
# 309     --    REBOUND DEF  Opponent
# 310  00:00      GOOD 3PTR  Opponent
# 311     --        ASSIST   Opponent

# %%
def time_passed(start, end):
    if (start == "--") and (end == "02:34"):
        return 21
    if (start == "10:39") and (end == "--"):
        return 0
    
    start_time = int(start.split(":")[0])*60 + int(start.split(":")[1])
    end_time = int(end.split(":")[0])*60 + int(end.split(":")[1])
    
    if start_time > end_time:
        return start_time - end_time
    else:
        return 0

# %%
def possession_length(df):
    possessions = []
    current = 1
    for x in range(0, len(df)):
        indexer = df.shape[0] - x - 1
        if ('MISS' in df.Action.values[indexer]) | ('GOOD' in df.Action.values[indexer]) | ('TURNOVER' in df.Action.values[indexer]):
            possessions.append(current)
            current += 1
        else:
            possessions.append(current)

    df['Possession'] = possessions[::-1]

    lengths = []
    outcomes = []
    for x in pd.unique(df.Possession):
        new_df = pd.concat([df[(df.Possession == x)],
                            df[(df.index == 1 + df[(df.Possession == x)].index.values[-1])] ])

        new_df = new_df[(~new_df.Action.str.contains("SUB")) & (~new_df.Action.str.contains("TIMEOUT"))]

        if "FT" in new_df.Action.values[-1]:
            outcome = "Shooting Foul"
        elif "MISS" in new_df.Action.values[-1]:
            outcome = "Miss"
        elif "GOOD" in new_df.Action.values[-1]:
            outcome = "Make"
        elif "TURNOVER" in new_df.Action.values[-1]:
            outcome = "Turnover"
        else:
            outcome = "FLAG"

        start = new_df.Time.values[0]
        if new_df.Time.values[-1] == '--':
            end = new_df.Time.values[-2]
        else:
            end = new_df.Time.values[-1]

        if new_df.Team.values[-1] == 'Colorado':
            new_df['new'] = new_df.Action.apply(lambda i : "FT" in i)
            if (new_df.new.sum() <= 1) and (outcome != "FLAG"):
                lengths.append(time_passed(start, end))
                outcomes.append(outcome)
            
    return pd.DataFrame({'Length' : lengths, 'Outcome' : outcomes})

# %%
colorado = pd.concat([possession_length(df1),
                      possession_length(df2),
                      possession_length(df3),
                      possession_length(df4)])

# %%
colorado['<10sec'] = colorado.Length < 10
colorado['>=10sec'] = colorado.Length >= 10

# %%
under10 = colorado[(colorado['<10sec'])].groupby('Outcome').count()
under10['Count'] = under10['Length']
under10['%'] = 100 * round(under10.Count / sum(under10.Count), 3)

print("Possessions lasting <10 seconds:")
display(under10[['Count', '%']])



over10 = colorado[(colorado['>=10sec'])].groupby('Outcome').count()
over10['Count'] = over10['Length']
over10['%'] = 100 * round(over10.Count / sum(over10.Count), 3)

print("Possessions lasting 10+ seconds:")
display(over10[['Count', '%']])
# Out:
# Possessions lasting <10 seconds:
#                Count     %
# Outcome
# Make              19  27.9
# Miss              19  27.9
# Shooting Foul     16  23.5
# Turnover          14  20.6
# Possessions lasting 10+ seconds:
#                Count     %
# Outcome
# Make              27  24.3
# Miss              47  42.3
# Shooting Foul      6   5.4
# Turnover          31  27.9

# %%
by_length = colorado.groupby("<10sec").count()

by_length['Count'] = by_length.Length
by_length['%'] = 100 * round(by_length.Count / sum(by_length.Count), 3)

by_length['Possession Length'] = by_length.index.map({False : "10+ sec", True : "<10 sec"})
by_length.index = by_length['Possession Length']

by_length[['Count', '%']].sort_values(by='Possession Length', ascending=False)
# Out:
#                    Count     %
# Possession Length
# <10 sec               68  38.0
# 10+ sec              111  62.0

# %%
colorado.Length.mean().round(1)
# Out:
# 14.2
