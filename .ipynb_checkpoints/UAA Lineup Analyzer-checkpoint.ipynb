# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
uchicago = pd.read_csv("season_plays23.csv").iloc[:, 1:]
w_uchicago = pd.read_csv("w_season_plays23.csv").iloc[:, 1:]

# %%
def points_scored(action):
    if "3-pt" in action:
        return 3
    elif "free throw" in action:
        return 1
    else:
        return 2
    
def calculate_scores(df, lineup):
    current = df[df.Lineup == lineup]
    
    makes = current[current.Action.str.contains('made')]
    makes["Points"] = makes.Action.apply(points_scored)

    chicago_scores = makes[makes.Chicago == makes.Team].Points.sum()
    other_scores = makes[makes.Chicago != makes.Team].Points.sum()

    return (chicago_scores, other_scores)

def calculate_play(df, lineup, play):
    current = df[df.Lineup == lineup]
    plays = current[(current.Action.str.contains(play))]

    chicago = plays[(plays.Chicago == plays.Team)].shape[0]
    other = plays[(plays.Chicago != plays.Team)].shape[0]
    
    return (chicago, other)

def calculate_makes(df, lineup, three=False, ft=False):
    current = df[df.Lineup == lineup]
    
    makes = current[current.Action.str.contains("made")]
    if three:
        makes = makes[makes.Action.str.contains("3-pt")]
    elif ft:
        makes = makes[makes.Action.str.contains("free throw")]
    else:
        makes = makes[~makes.Action.str.contains("free throw")]
    
    chicago_makes = makes[(makes.Chicago == makes.Team)].shape[0]
    other_makes = makes[(makes.Chicago != makes.Team)].shape[0]
    
    return (chicago_makes, other_makes)

def calculate_percentage(df, lineup, three=False, ft=False, att=False):
    current = df[df.Lineup == lineup]
    misses = current[(current.Action.str.contains("missed"))]
    makes = current[(current.Action.str.contains("made"))]
    
    if three:
        misses = misses[misses.Action.str.contains("3-pt")]
        makes = makes[makes.Action.str.contains("3-pt")]
    elif ft:
        misses = misses[misses.Action.str.contains("free throw")]
        makes = makes[makes.Action.str.contains("free throw")]
    else:
        misses = misses[~(misses.Action.str.contains("free throw"))]
        makes = makes[~(makes.Action.str.contains("free throw"))]
        
    chicago_misses = misses[(misses.Chicago == misses.Team)].shape[0]
    chicago_makes = makes[(makes.Chicago == makes.Team)].shape[0]
    other_misses = misses[(misses.Chicago != misses.Team)].shape[0]
    other_makes = makes[(makes.Chicago != makes.Team)].shape[0]
    
    chicago_attempts = chicago_misses + chicago_makes
    other_attempts = other_misses + other_makes
    
    if att:
        return (chicago_attempts, other_attempts)
    
    if (chicago_attempts == 0) and (other_attempts == 0):
        return (0, 0)
    elif chicago_attempts == 0:
        return (0, other_makes / other_attempts)
    elif other_attempts == 0:
        return (chicago_makes / chicago_attempts, 0)
    else:
        return (chicago_makes / chicago_attempts, 
                other_makes / other_attempts)
    
def sec_to_time(seconds):
    minutes = str(seconds // 60)
    
    if (seconds % 60) < 10:
        return minutes + ":0" + str(seconds % 60)
    else:
        return minutes + ":" + str(seconds % 60)

def time_passed(start, end):
    if start == '30300':
        start = "00:30"
    elif end == '30300':
        end = "00:30"
    
    start_time = int(start.split(":")[0])*60 + int(start.split(":")[1])
    end_time = int(end.split(":")[0])*60 + int(end.split(":")[1])
    
    if start_time > end_time:
        return start_time - end_time
    else:
        return 0

def calculate_time_played(df, lineup):
    total_time = 0
    for x in range(len(df[df.Lineup == lineup])-1):
        current_play = df[df.Lineup == lineup].reset_index(drop=False).values[x]
        next_play = df[df.Lineup == lineup].reset_index(drop=False).values[x+1]
        if x > 0:
            last_play = df[df.Lineup == lineup].reset_index(drop=False).values[x-1]
        else:
            last_play = current_play

        if (current_play[0] != next_play[0] - 1) or (current_play[0] == 342):
            continue
            
        if (current_play[0] == 0) or (last_play[4] != current_play[4]):
            continue
        elif next_play[4] != current_play[4]:
            start = current_play[5]
            end = "00:00"
        else:
            start = current_play[5]
            end = next_play[5]

        total_time += time_passed(start, end)

    return total_time / 60

def analyze_lineup(df, lineup):
    return [calculate_time_played(df, lineup), # MP
            
            calculate_scores(df, lineup)[0], # PTS
            calculate_scores(df, lineup)[1], # OPP PTS
            
            calculate_scores(df, lineup)[0] - calculate_scores(df, lineup)[1], # +/-
            
            calculate_play(df, lineup, "Assist")[0], # AST
            
            calculate_play(df, lineup, "offensive rebound")[0], # OREB
            calculate_play(df, lineup, "offensive rebound")[1], # OPP OREB
            calculate_play(df, lineup, "defensive rebound")[0], # DREB
            calculate_play(df, lineup, "defensive rebound")[1], # OPP DREB
            
            calculate_makes(df, lineup)[0], # FGM
            calculate_percentage(df, lineup, att=True)[0], # FGA
            calculate_makes(df, lineup)[1], # OPP FGM
            calculate_percentage(df, lineup, att=True)[1], # OPP FGA
            
            calculate_makes(df, lineup, three=True)[0], # 3PM
            calculate_percentage(df, lineup, three=True, att=True)[0], # 3PA
            calculate_makes(df, lineup, three=True)[1], # OPP 3PM
            calculate_percentage(df, lineup, three=True, att=True)[1], # OPP 3PA
            
            calculate_makes(df, lineup, ft=True)[0], # FTM
            calculate_makes(df, lineup, ft=True)[1], # OPP FTM
            calculate_percentage(df, lineup, ft=True, att=True)[0], # FTA
            calculate_percentage(df, lineup, ft=True, att=True)[1], # OPP FTA
            
            calculate_play(df, lineup, "Turnover")[0], # TO
            calculate_play(df, lineup, "Turnover")[1],# OPP TO
            
            calculate_play(df, lineup, "Steal")[0], # STL
            calculate_play(df, lineup, "Block")[0], # BLK
            
            calculate_play(df, lineup, "Foul")[0], # PF
            calculate_play(df, lineup, "Foul")[1]] # OPP PF

def pbp_lineups(game_pbp):
    date = game_pbp.Date.values[0]
    lineups = [l for l in pd.unique(game_pbp.Lineup) if len(l.split(", ")) == 5]

    lineup_data = []
    for line in lineups:
        lineup_data.append( [line] + analyze_lineup(game_pbp, line) )

    lineup_analysis = pd.DataFrame(lineup_data, 
                                   columns = ['Lineup',
                                              'MP', 
                                              'PTS', 'OPP PTS', 
                                              '+/-', 
                                              'AST',
                                              'OREB', 'OPP OREB', 'DREB', 'OPP DREB',
                                              'FGM', 'FGA', 'OPP FGM', 'OPP FGA',
                                              '3PM', '3PA', 'OPP 3PM', 'OPP 3PA',
                                              'FTM', 'OPP FTM', 'FTA', 'OPP FTA', 
                                              'TO', 'OPP TO', 
                                              'STL', 'BLK',
                                              'PF', 'OPP PF'])
    
    lineup_analysis['Lineup_Set'] = lineup_analysis.Lineup.apply(lambda i : set(i.split(", ")))
    lineup_analysis['Lineup'] = lineup_analysis['Lineup_Set'].apply(lambda i : ", ".join(sorted(i)))
    lineup_analysis = lineup_analysis.groupby('Lineup').sum().reset_index(drop=False)
    
    return lineup_analysis

# %%
def add_advanced(lineup_analysis):
    lineup_analysis['FG%'] = 100 * lineup_analysis['FGM'] / lineup_analysis['FGA']
    lineup_analysis['OPP FG%'] = 100 * lineup_analysis['FGM'] / lineup_analysis['FGA']
    lineup_analysis['3P%'] = 100 * lineup_analysis['3PM'] / lineup_analysis['3PA']
    lineup_analysis['OPP 3P%'] = 100 * lineup_analysis['OPP 3PM'] / lineup_analysis['OPP 3PA']
    lineup_analysis['FT%'] = 100 * lineup_analysis['FTM'] / lineup_analysis['FTA']
    lineup_analysis['OPP FT%'] = 100 * lineup_analysis['OPP FTM'] / lineup_analysis['OPP FTA']
    
    # formula from nbastuffer.com
    lineup_analysis['POSS'] = 0.96 * (lineup_analysis.FGA +
                                      lineup_analysis.TO + 
                                      0.44*(lineup_analysis.FTA) - 
                                      lineup_analysis.OREB)
    lineup_analysis['OPP POSS'] = 0.96 * (lineup_analysis['OPP FGA'] +
                                          lineup_analysis['OPP TO'] + 
                                          0.44*(lineup_analysis['OPP FTA']) - 
                                          lineup_analysis['OPP OREB'])

    lineup_analysis['PPP'] = lineup_analysis.PTS / lineup_analysis.POSS
    lineup_analysis['OPP PPP'] = lineup_analysis['OPP PTS'] / lineup_analysis['OPP POSS']
    
    lineup_analysis['FTA%'] = 100 * lineup_analysis['FTA'].astype(int) / lineup_analysis['FGA'].astype(int)
    lineup_analysis['OPP FTA%'] = 100 * lineup_analysis['OPP FTA'].astype(int) / lineup_analysis['OPP FGA'].astype(int)

    lineup_analysis['PTS DIFF PER40'] = 40 * (lineup_analysis['PTS'] - lineup_analysis['OPP PTS']) / lineup_analysis['MP']

    lineup_analysis['REB'] = lineup_analysis.OREB + lineup_analysis.DREB
    lineup_analysis['OPP REB'] = lineup_analysis['OPP OREB'] + lineup_analysis['OPP DREB']
    lineup_analysis['ORB%'] = 100 * lineup_analysis.OREB / (lineup_analysis.OREB + lineup_analysis['OPP DREB'])
    lineup_analysis['DRB%'] = 100 * lineup_analysis.DREB / (lineup_analysis.DREB + lineup_analysis['OPP OREB'])
    lineup_analysis['RB%'] = 100 * lineup_analysis.REB / (lineup_analysis.REB + lineup_analysis['OPP REB'])
    lineup_analysis['OPP ORB%'] = 100 * lineup_analysis['OPP OREB'] / (lineup_analysis['OPP OREB'] + lineup_analysis.DREB)
    lineup_analysis['OPP DRB%'] = 100 * lineup_analysis['OPP DREB'] / (lineup_analysis['OPP DREB'] + lineup_analysis.OREB)
    lineup_analysis['OPP RB%'] = 100 * lineup_analysis['OPP REB'] / (lineup_analysis['OPP REB'] + lineup_analysis.REB)

    lineup_analysis['TO%'] = 100 * lineup_analysis.TO / lineup_analysis.POSS
    lineup_analysis['OPP TO%'] = 100 * lineup_analysis['OPP TO'] / lineup_analysis['OPP POSS']
    
    lineup_analysis['POSS PER40'] = 40 * lineup_analysis['POSS'] / lineup_analysis['MP']
    
    lineup_analysis = lineup_analysis.round(2)
    lineup_analysis['POSS'] = lineup_analysis['POSS'].round(1)
    lineup_analysis['OPP POSS'] = lineup_analysis['OPP POSS'].round(1)
    lineup_analysis['ORB%'] = lineup_analysis['ORB%'].round(1)
    lineup_analysis['DRB%'] = lineup_analysis['DRB%'].round(1)
    lineup_analysis['RB%'] = lineup_analysis['RB%'].round(1)
    lineup_analysis['TO%'] = lineup_analysis['TO%'].round(1)
    lineup_analysis['OPP ORB%'] = lineup_analysis['OPP ORB%'].round(1)
    lineup_analysis['OPP DRB%'] = lineup_analysis['OPP DRB%'].round(1)
    lineup_analysis['OPP RB%'] = lineup_analysis['OPP RB%'].round(1)
    lineup_analysis['OPP TO%'] = lineup_analysis['OPP TO%'].round(1)
    lineup_analysis['FTA%'] = lineup_analysis['FTA%'].round(1)
    lineup_analysis['OPP FTA%'] = lineup_analysis['OPP FTA%'].round(1)
    
    return lineup_analysis

def pbp_helper(df):
    lineup_data = []
    for x in pd.unique(df.Opponent):
        lineup_data.append( pbp_lineups( df[(df.Opponent == x)] ) )
        
    lineup_analysis = pd.concat(lineup_data)
    lineup_analysis = lineup_analysis.groupby('Lineup').sum()
        
    lineup_analysis = add_advanced(lineup_analysis)
    
    lineup_analysis = lineup_analysis.fillna(0).sort_values(by='MP', ascending=False)
    
    lineup_analysis['Lineup'] = lineup_analysis.index
    lineup_analysis.Lineup = lineup_analysis.Lineup.apply(lambda l : ", ".join([i.split(" ")[0] for i in l.split(", ")]))
    
    return lineup_analysis.set_index('Lineup')

def win_loss(margin):
    if margin > 0:
        return "W"
    else:
        return "L"

def game_helper( game_pbp ):
    df = game_pbp.copy()
    df['Lineup'] = df.Game.apply(lambda i : ", ".join([str(i)] * 5))

    lineup_data = []
    for x in pd.unique(df.Game):
        lineup_data.append( [pbp_lineups( df[(df.Game == x)] ), x] )

    lineup_analysis = pd.concat( [i[0] for i in lineup_data] )
    lineup_analysis['Game'] = [i[1] for i in lineup_data]

    lineup_analysis = add_advanced(lineup_analysis)
    lineup_analysis['Lineup'] = list(pd.DataFrame(game_pbp.groupby(by=['Date', 'Opponent'])['Game'].first()).sort_values(by=['Game']).reset_index(drop=False).Opponent)

    lineup_analysis = lineup_analysis.set_index("Lineup")

    lineup_analysis['Margin'] = (lineup_analysis['PTS'].astype(int) - lineup_analysis['OPP PTS'].astype(int))
    lineup_analysis['W/L'] = lineup_analysis.Margin.apply(win_loss)

    lineup_analysis = lineup_analysis[['W/L', 'Margin', 'POSS', 'OPP POSS', 'PPP', 'OPP PPP', 'FTA%', 'OPP FTA%', 'PTS DIFF PER40', 'REB', 'OPP REB', 'ORB%', 'DRB%', 'RB%', 'TO%', 'OPP TO%']]

    return lineup_analysis.fillna(0)

def total_advanced(game_pbp, uaa=False):
    df = game_pbp.copy()
    
    if uaa:
        df = df[(df.Opponent.isin(['Washington-St. Louis', 'New York U.', 'Brandeis', 
                                   'Carnegie Mellon', 'Case Western Reserve',
                                   'Emory', 'Rochester (N.Y.)']))]

    df['Lineup'] = ", ".join(['Total']*5)
    
    lineup_analysis = pbp_lineups(df)
    
    lineup_analysis = add_advanced(lineup_analysis)
    
    lineup_analysis['POSS'] = round(40 * lineup_analysis['POSS'] / lineup_analysis['MP'], 1)
    lineup_analysis['OPP POSS'] = round(40 * lineup_analysis['OPP POSS'] / lineup_analysis['MP'], 1)
    lineup_analysis['W/L'] = ""
    lineup_analysis['Margin'] = lineup_analysis['PTS'].astype(int) - lineup_analysis['OPP PTS'].astype(int)
    
    lineup_analysis = lineup_analysis[['W/L', 'Margin', 'POSS', 'OPP POSS', 'PPP', 'OPP PPP', 'FTA%', 'OPP FTA%', 'PTS DIFF PER40', 'REB', 'OPP REB', 'ORB%', 'DRB%', 'RB%', 'TO%', 'OPP TO%']]
    lineup_analysis.index = ['Total']
    
    return lineup_analysis

# %%
team_start = "20:00"
current = uchicago
date = "February 25, 2023"

new = current[(current.Date == date)]
new['length'] = new.Lineup.apply(lambda i : len(i.split(", ")))

print(pbp_helper( current[(current.Date == date)] ).MP.sum())
display(new[(new.length != 5) & (new.Substitution == 0)])
# Out:
# 39.209999999999994
# Empty DataFrame
# Columns: [Date, Chicago, Opponent, Half, Time, Score, Team, Action, Substitution, Player, Lineup, Points, Game, length]
# Index: []

# %%
lineups = pbp_helper( current )

lineups
# Out:
#                                              MP  PTS  OPP PTS  +/-  AST  OREB  \
# Lineup
# Bryce, Eamonn, Jackson, Joe, Thomas      101.28  162      184  -22   27    27
# Arrish, Bryce, Eamonn, Joe, Thomas        97.42  170      154   16   34    24
# Arrish, Bryce, Ezra, Joe, Thomas          46.18   70       67    3   13    11
# Alec, Arrish, Elliot, Ezra, Thomas        39.78   68       48   20   13    13
# Bryce, Elliot, Jackson, Joe, Thomas       35.55   60       73  -13   10     4
# Bryce, Elliot, Ezra, Jackson, Thomas      27.23   32       50  -18    5     2
# Alec, Arrish, Ezra, Joe, Thomas           26.10   43       29   14    8     8
# Bryce, Ezra, Jackson, Joe, Thomas         22.65   61       30   31   12     1
# Bryce, Eamonn, Ezra, Jackson, Joe         20.48   45       41    4    9     3
# Arrish, Bryce, Eamonn, Elliot, Joe        18.50   38       29    9    7     6
# Alec, Arrish, Eamonn, Joe, Thomas         16.53   35       30    5    8     8
# Bryce, Eamonn, Elliot, Jackson, Joe       12.87   28       35   -7    4     2
# Arrish, Bryce, Elliot, Ezra, Thomas       12.35   29       29    0    7     0
# Alec, Eamonn, Jackson, Joe, Thomas        12.15   24       16    8    2     3
# Alec, Arrish, Eamonn, Elliot, Joe         11.98   17       28  -11    3     3
# Alec, Eamonn, Ezra, Jackson, Joe          11.20   19       24   -5    2     3
# Arrish, Bryce, Elliot, Joe, Thomas        10.73   15       16   -1    4     1
# Bryce, Elliot, Ezra, Jackson, Joe         10.40   14       19   -5    2     1
# Bryce, Elliot, Ezra, Josh, Thomas         10.10   16       14    2    5     3
# Arrish, Bryce, Eamonn, Ezra, Joe          10.05   25       16    9    6     4
# Eamonn, Joe, Josh, Leonardo, Skyler        9.78   22       14    8    6     3
# Bryce, Eammon, Jackson, Joe, Thomas        9.62   22       22    0    3     2
# Alec, Ezra, Joe, Josh, Thomas              9.20   10       21  -11    3     4
# Arrish, Bryce, Eamonn, Elliot, Thomas      8.88   17       17    0    5     3
# Alec, Alex, Eamonn, Elliot, Joe            8.28   13        9    4    2     1
# Alex, Bryce, Eamonn, Joe, Thomas           7.93   13       17   -4    1     3
# Arrish, Eamonn, Jackson, Skyler, Thomas    7.35   12       18   -6    2     1
# Alec, Elliot, Joe, Josh, Skyler            7.17   13       11    2    2     4
# Alec, Bryce, Eamonn, Joe, Thomas           6.83    8       13   -5    1     2
# Alec, Alex, Ezra, Joe, Thomas              6.77    5       11   -6    0     1
# Arrish, Joe, Leonardo, Skyler, Thomas      6.28   12        8    4    2     1
# Alec, Ezra, Joe, Josh, Skyler              6.10   11       10    1    2     2
# Bryce, Eamonn, Elliot, Jackson, Thomas     6.07   11        5    6    1     2
# Alec, Arrish, Ezra, Skyler, Thomas         5.97    8       19  -11    1     1
# Arrish, Bryce, Eammon, Joe, Thomas         5.87   11        5    6    1     3
# Elliot, Jackson, Joe, Josh, Thomas         5.75   10        8    2    3     2
# Alec, Bryce, Elliot, Joe, Thomas           5.73   22       14    8    4     1
# Bryce, Ezra, Jackson, Joe, Skyler          5.67    2        8   -6    0     3
# Alec, Bryce, Eamonn, Ezra, Joe             5.65   10        1    9    2     2
# Arrish, Bryce, Eamonn, Elliot, Ezra        5.32    8       15   -7    1     2
# Bryce, Eamonn, Jackson, Skyler, Thomas     4.93   11        7    4    4     2
# Arrish, Ezra, Joe, Leonardo, Thomas        4.92    7        6    1    1     2
# Alec, Arrish, Eamonn, Ezra, Joe            4.92    6       13   -7    0     1
# Ezra, Joe, Josh, Leonardo, Thomas          4.87   10        7    3    2     2
# Ezra, Jackson, Joe, Josh, Thomas           4.62   11       10    1    3     0
# Alec, Alex, Elliot, Ezra, Joe              4.45   13        4    9    2     2
# Arrish, Eamonn, Elliot, Joe, Skyler        4.42   10        8    2    2     2
# Arrish, Elliot, Joe, Leonardo, Thomas      4.38    9       10   -1    1     1
# Alec, Ezra, Jackson, Joe, Thomas           4.37    4        5   -1    1     0
# Arrish, Bryce, Elliot, Ezra, Joe           4.30    6        7   -1    2     0
# Alec, Arrish, Eamonn, Elliot, Thomas       4.25    4        7   -3    1     1
# Alex, Jackson, Joe, Skyler, Thomas         4.23    8        3    5    2     2
# Alex, Bryce, Eamonn, Elliot, Joe           4.07    3        3    0    1     1
# Arrish, Eamonn, Jackson, Joe, Thomas       4.05    7        8   -1    2     1
# Elliot, Ezra, Joe, Josh, Leonardo          4.02    7        4    3    2     3
# Elliot, Jackson, Joe, Josh, Skyler         4.02    4        5   -1    0     1
# Alec, Elliot, Jackson, Joe, Thomas         4.02   12        3    9    3     1
# Bryce, Eamonn, Jackson, Joe, Skyler        3.88    3        2    1    1     1
# Alec, Elliot, Ezra, Jackson, Thomas        3.87    7        9   -2    0     3
# Ezra, Joe, Josh, Leonardo, Skyler          3.75    6        4    2    2     2
# Eamonn, Jackson, Josh, Skyler, Thomas      3.73    2        8   -6    0     0
# Ezra, Jackson, Joe, Josh, Skyler           3.70    3        6   -3    1     0
# Alec, Alex, Ezra, Skyler, Thomas           3.60    4        7   -3    1     2
# Arrish, Bryce, Eamonn, Joe, Skyler         3.58    7        6    1    2     0
# Alec, Bryce, Eamonn, Elliot, Joe           3.57    6        2    4    1     0
# Elliot, Joe, Josh, Leonardo, Thomas        3.57    4        8   -4    0     1
# Alec, Alex, Eamonn, Joe, Thomas            3.55    3        5   -2    0     0
# Alec, Alex, Eamonn, Skyler, Thomas         3.52    6        8   -2    2     0
# Alec, Arrish, Ezra, Joe, Skyler            3.43   12        4    8    4     2
# Alec, Arrish, Elliot, Joe, Thomas          3.42    6        5    1    0     2
# Bryce, Elliot, Jackson, Joe, Skyler        3.35    6        9   -3    2     0
# Alex, Joe, Leonardo, Skyler, Thomas        3.28    6        5    1    1     1
# Alec, Bryce, Eamonn, Joe, Skyler           3.25    4       11   -7    1     1
# Alec, Alex, Eamonn, Ezra, Joe              3.20   10        5    5    1     2
# Alex, Eamonn, Jackson, Joe, Skyler         3.17    6        6    0    1     2
# Alec, Elliot, Ezra, Joe, Josh              3.13    5        3    2    1     0
# Bryce, Jackson, Joe, Skyler, Thomas        3.12    6        7   -1    2     0
# Arrish, Eamonn, Ezra, Jackson, Joe         3.07    2        6   -4    0     1
# Alec, Eamonn, Joe, Josh, Skyler            3.02    8        5    3    1     2
# Alec, Arrish, Bryce, Joe, Skyler           3.02    4        7   -3    0     1
# Alec, Bryce, Ezra, Joe, Thomas             2.93    6        5    1    0     3
# Alec, Bryce, Elliot, Ezra, Thomas          2.88    3        5   -2    0     0
# Arrish, Jackson, Joe, Skyler, Thomas       2.83    5        5    0    1     0
# Alex, Ben, Dashiel, Jackson, Skyler        2.83    8        0    8    2     2
# Bryce, Elliot, Jackson, Skyler, Thomas     2.80    6        4    2    1     0
# Alec, Eamonn, Ezra, Joe, Josh              2.78    5        5    0    2     1
# Arrish, Ezra, Jackson, Joe, Thomas         2.77    5        7   -2    0     0
# Alec, Arrish, Joe, Skyler, Thomas          2.70    6        3    3    1     0
# Bryce, Eamonn, Elliot, Ezra, Jackson       2.70    0        7   -7    0     1
# Alec, Elliot, Joe, Josh, Thomas            2.67    7        1    6    1     1
# Arrish, Bryce, Eamonn, Ezra, Thomas        2.62    6        2    4    2     1
# Alex, Eamonn, Joe, Leonardo, Skyler        2.62    2        9   -7    0     0
# Alex, Bryce, Ezra, Joe, Thomas             2.57    3        6   -3    0     0
# Arrish, Ezra, Jackson, Joe, Skyler         2.57    0        4   -4    0     2
# Alec, Alex, Elliot, Joe, Thomas            2.55    2        6   -4    0     1
# Bryce, Eamonn, Elliot, Joe, Thomas         2.52    6        4    2    0     1
# Arrish, Bryce, Ezra, Skyler, Thomas        2.48    5        2    3    2     1
# Alex, Ezra, Jackson, Joe, Thomas           2.42    4        3    1    1     3
# Alex, Eamonn, Jackson, Joe, Thomas         2.42    2        6   -4    0     1
# Eamonn, Jackson, Joe, Leonardo, Thomas     2.37    5        4    1    1     1
# Eamonn, Jackson, Joe, Josh, Skyler         2.33    6        6    0    2     0
# Joe, Josh, Leonardo, Skyler, Thomas        2.27    2        5   -3    0     1
# Alec, Eammon, Jackson, Joe, Skyler         2.25    6        5    1    2     0
# Eamonn, Ezra, Jackson, Joe, Skyler         2.18    7        2    5    1     0
# Eamonn, Joe, Josh, Leonardo, Thomas        2.17    5        2    3    1     1
# Alex, Ezra, Joe, Josh, Skyler              2.15    1        4   -3    0     1
# Bryce, Ezra, Joe, Leonardo, Thomas         2.15    1        2   -1    0     2
# Alex, Elliot, Jackson, Joe, Thomas         2.13    3        4   -1    1     0
# Alex, Bryce, Elliot, Ezra, Thomas          2.05    2        6   -4    0     0
# Arrish, Bryce, Ezra, Joe, Skyler           2.00    4        0    4    1     0
# Alex, Bryce, Eamonn, Elliot, Ezra          2.00    2        8   -6    0     0
# Alec, Bryce, Eamonn, Skyler, Thomas        1.97    4        4    0    0     0
# Alex, Bryce, Eamonn, Ezra, Joe             1.95    9        2    7    1     1
# Alec, Arrish, Eamonn, Jackson, Joe         1.93    5        4    1    1     0
# Alec, Arrish, Elliot, Skyler, Thomas       1.83    2        2    0    0     1
# Alec, Alex, Eamonn, Joe, Skyler            1.80    2        3   -1    0     1
# Bryce, Eamonn, Joe, Josh, Thomas           1.60    1        2   -1    0     1
# Alec, Elliot, Jackson, Skyler, Thomas      1.58    2        2    0    0     0
# Arrish, Ezra, Leonardo, Skyler, Thomas     1.58    2        0    2    0     0
# Alec, Eamonn, Jackson, Skyler, Thomas      1.58    3        7   -4    1     0
# Ben, Dashiel, Jackson, Joe, Josh           1.55    2        2    0    0     0
# Alec, Eamonn, Elliot, Jackson, Joe         1.52    3        6   -3    1     0
# Arrish, Elliot, Ezra, Jackson, Thomas      1.48    2        3   -1    0     0
# Arrish, Bryce, Eamonn, Skyler, Thomas      1.42    2        6   -4    1     0
# Alec, Bryce, Joe, Skyler, Thomas           1.42    6        7   -1    0     0
# Alec, Alex, Elliot, Ezra, Thomas           1.38    0        0    0    0     2
# Bryce, Ezra, Jackson, Skyler, Thomas       1.35    2        0    2    0     0
# Alec, Elliot, Ezra, Josh, Thomas           1.35    5        7   -2    1     1
# Bryce, Eamonn, Elliot, Ezra, Leonardo      1.33    0        2   -2    0     0
# Ezra, Josh, Leonardo, Skyler, Thomas       1.25    3        0    3    1     0
# Elliot, Ezra, Josh, Leonardo, Thomas       1.15    0        0    0    0     1
# Alec, Bryce, Elliot, Ezra, Joe             1.12    0        4   -4    0     0
# Alex, Ezra, Jackson, Skyler, Thomas        1.12    0        0    0    0     1
# Elliot, Ezra, Jackson, Leonardo, Skyler    1.12    0        3   -3    0     0
# Alec, Arrish, Bryce, Eamonn, Joe           1.10    2        0    2    1     0
# Alex, Elliot, Ezra, Leonardo, Thomas       1.10    3        0    3    0     0
# Alec, Elliot, Ezra, Jackson, Joe           1.07    2        4   -2    0     0
# Alex, Elliot, Ezra, Joe, Leonardo          1.05    4        0    4    1     0
# Elliot, Ezra, Josh, Skyler, Thomas         1.03    3        2    1    0     0
# Alec, Alex, Ezra, Joe, Skyler              1.00    3        3    0    1     0
# Arrish, Bryce, Eamonn, Ezra, Skyler        0.98    2        0    2    1     0
# Eamonn, Elliot, Joe, Josh, Leonardo        0.95    0        2   -2    0     0
# Alex, Eamonn, Joe, Leonardo, Thomas        0.95    0        2   -2    0     0
# Arrish, Eamonn, Elliot, Joe, Leonardo      0.90    4        2    2    1     0
# Bryce, Eamonn, Ezra, Joe, Leonardo         0.88    2        0    2    0     0
# Arrish, Bryce, Elliot, Skyler, Thomas      0.87    2        4   -2    0     0
# Bryce, Eammon, Joe, Skyler, Thomas         0.87    0        4   -4    0     0
# Bryce, Elliot, Ezra, Jackson, Skyler       0.85    2        0    2    0     0
# Arrish, Bryce, Eamonn, Jackson, Joe        0.80    3        0    3    1     1
# Alec, Alex, Dashiel, Leonardo, Skyler      0.80    0        6   -6    0     0
# Arrish, Ezra, Jackson, Skyler, Thomas      0.77    0        3   -3    0     1
# Alec, Jackson, Joe, Skyler, Thomas         0.75    0        3   -3    0     1
# Eamonn, Elliot, Jackson, Joe, Leonardo     0.73    0        2   -2    0     0
# Alec, Alex, Elliot, Ezra, Skyler           0.70    2        3   -1    0     1
# Arrish, Elliot, Joe, Leonardo, Skyler      0.60    2        0    2    0     1
# Jackson, Joe, Josh, Skyler, Thomas         0.58    1        3   -2    0     0
# Alec, Ezra, Josh, Skyler, Thomas           0.58    3        0    3    1     0
# Alec, Eamonn, Elliot, Jackson, Thomas      0.55    3        0    3    1     0
# Alec, Ezra, Joe, Leonardo, Skyler          0.53    0        3   -3    0     0
# Arrish, Bryce, Eamonn, Ezra, Jackson       0.53    2        0    2    0     0
# Alex, Eamonn, Joe, Skyler, Thomas          0.48    0        2   -2    0     0
# Alec, Arrish, Eammon, Joe, Skyler          0.47    0        0    0    0     0
# Alec, Alex, Eamonn, Elliot, Ezra           0.47    0        2   -2    0     0
# Bryce, Eamonn, Elliot, Skyler, Thomas      0.47    0        2   -2    0     0
# Alex, Bryce, Elliot, Joe, Thomas           0.45    3        2    1    1     0
# Alec, Alex, Joe, Skyler, Thomas            0.43    1        0    1    0     0
# Alec, Bryce, Ezra, Jackson, Skyler         0.40    0        0    0    0     0
# Bryce, Eamonn, Ezra, Jackson, Skyler       0.38    3        0    3    1     0
# Arrish, Eamonn, Joe, Leonardo, Skyler      0.37    2        0    2    0     0
# Bryce, Eammon, Elliot, Joe, Thomas         0.33    0        2   -2    0     0
# Alec, Bryce, Ezra, Joe, Skyler             0.30    0        0    0    0     0
# Elliot, Ezra, Joe, Josh, Thomas            0.30    0        2   -2    0     0
# Alec, Arrish, Eammon, Skyler, Thomas       0.28    0        2   -2    0     0
# Alec, Bryce, Elliot, Jackson, Joe          0.28    1        0    1    0     0
# Alec, Eamonn, Jackson, Joe, Skyler         0.23    0        1   -1    0     0
# Bryce, Eamonn, Joe, Skyler, Thomas         0.22    2        3   -1    0     0
# Alec, Ben, Leonardo, Skyler, Thomas        0.22    0        0    0    0     0
# Alec, Ben, Jackson, Skyler, Thomas         0.20    1        0    1    0     0
# Alex, Eamonn, Elliot, Joe, Leonardo        0.15    0        0    0    0     0
# Alec, Arrish, Elliot, Jackson, Joe         0.15    0        0    0    0     0
# Alex, Ezra, Jackson, Joe, Skyler           0.13    0        2   -2    0     0
# Bryce, Eammon, Elliot, Jackson, Joe        0.08    0        0    0    0     0
# Arrish, Elliot, Ezra, Joe, Thomas          0.08    2        0    2    0     0
# Elliot, Ezra, Joe, Skyler, Thomas          0.03    0        0    0    0     0
# Arrish, Bryce, Eamonn, Jackson, Thomas     0.02    0        0    0    0     0
# Ben, Ezra, Jackson, Joe, Josh              0.00    0        1   -1    0     0
# Ezra, Jackson, Joe, Leonardo, Skyler       0.00    0        0    0    0     0
# Elliot, Joe, Leonardo, Skyler, Thomas      0.00    0        0    0    0     0
# Alec, Arrish, Elliot, Jackson, Thomas      0.00    0        0    0    0     0
# Alec, Elliot, Josh, Leonardo, Thomas       0.00    0        0    0    0     0
# Jackson, Joe, Kerem, Skyler, Thomas        0.00    0        0    0    0     0
# Alec, Arrish, Elliot, Josh, Thomas         0.00    0        0    0    0     0
#
#                                          OPP OREB  DREB  OPP DREB  FGM  FGA  \
# Lineup
# Bryce, Eamonn, Jackson, Joe, Thomas            27    63        72   59  154
# Arrish, Bryce, Eamonn, Joe, Thomas             22    72        63   58  145
# Arrish, Bryce, Ezra, Joe, Thomas                7    28        31   23   61
# Alec, Arrish, Elliot, Ezra, Thomas             13    33        25   28   65
# Bryce, Elliot, Jackson, Joe, Thomas            11    30        23   19   40
# Bryce, Elliot, Ezra, Jackson, Thomas            3    18        24   11   37
# Alec, Arrish, Ezra, Joe, Thomas                10    21        17   15   38
# Bryce, Ezra, Jackson, Joe, Thomas               2    13         9   22   32
# Bryce, Eamonn, Ezra, Jackson, Joe               7    14        10   16   27
# Arrish, Bryce, Eamonn, Elliot, Joe              5    14        12   11   28
# Alec, Arrish, Eamonn, Joe, Thomas               6     7        11   12   29
# Bryce, Eamonn, Elliot, Jackson, Joe             3     4         6    9   16
# Arrish, Bryce, Elliot, Ezra, Thomas             3     3         4   12   16
# Alec, Eamonn, Jackson, Joe, Thomas              2    14        11    8   20
# Alec, Arrish, Eamonn, Elliot, Joe               2     7         5    7   15
# Alec, Eamonn, Ezra, Jackson, Joe                2     7         8    7   19
# Arrish, Bryce, Elliot, Joe, Thomas              1     8         7    6   14
# Bryce, Elliot, Ezra, Jackson, Joe               3    10         7    6   14
# Bryce, Elliot, Ezra, Josh, Thomas               1     6         7    7   17
# Arrish, Bryce, Eamonn, Ezra, Joe                3     7         4   10   16
# Eamonn, Joe, Josh, Leonardo, Skyler             2     6         3   10   16
# Bryce, Eammon, Jackson, Joe, Thomas             0     6         7    5   13
# Alec, Ezra, Joe, Josh, Thomas                   2     4         7    4   14
# Arrish, Bryce, Eamonn, Elliot, Thomas           2     4         7    7   17
# Alec, Alex, Eamonn, Elliot, Joe                 2     7         5    3    9
# Alex, Bryce, Eamonn, Joe, Thomas                4     1         5    5   12
# Arrish, Eamonn, Jackson, Skyler, Thomas         0     2         2    5    8
# Alec, Elliot, Joe, Josh, Skyler                 2     3         3    5   11
# Alec, Bryce, Eamonn, Joe, Thomas                1     4         5    1    9
# Alec, Alex, Ezra, Joe, Thomas                   3     3         5    1    7
# Arrish, Joe, Leonardo, Skyler, Thomas           5     5         3    4    7
# Alec, Ezra, Joe, Josh, Skyler                   2     5         2    4    7
# Bryce, Eamonn, Elliot, Jackson, Thomas          1     7         6    2    8
# Alec, Arrish, Ezra, Skyler, Thomas              3     3         3    3    7
# Arrish, Bryce, Eammon, Joe, Thomas              6     2         1    3    6
# Elliot, Jackson, Joe, Josh, Thomas              1     2         2    3    7
# Alec, Bryce, Elliot, Joe, Thomas                2     2         5    6    9
# Bryce, Ezra, Jackson, Joe, Skyler               1     5         6    1   10
# Alec, Bryce, Eamonn, Ezra, Joe                  0     5         3    4    9
# Arrish, Bryce, Eamonn, Elliot, Ezra             0     1         2    4    8
# Bryce, Eamonn, Jackson, Skyler, Thomas          3     2         2    4    7
# Arrish, Ezra, Joe, Leonardo, Thomas             3     3         1    2    5
# Alec, Arrish, Eamonn, Ezra, Joe                 1     4         4    1    6
# Ezra, Joe, Josh, Leonardo, Thomas               1     1         2    4    7
# Ezra, Jackson, Joe, Josh, Thomas                0     2         4    4    7
# Alec, Alex, Elliot, Ezra, Joe                   1     3         2    4    8
# Arrish, Eamonn, Elliot, Joe, Skyler             1     4         4    3    9
# Arrish, Elliot, Joe, Leonardo, Thomas           3     1         4    2    4
# Alec, Ezra, Jackson, Joe, Thomas                2     4         3    2    5
# Arrish, Bryce, Elliot, Ezra, Joe                4     4         2    2    4
# Alec, Arrish, Eamonn, Elliot, Thomas            1     5         4    1    3
# Alex, Jackson, Joe, Skyler, Thomas              1     4         3    3    7
# Alex, Bryce, Eamonn, Elliot, Joe                1     3         2    1    5
# Arrish, Eamonn, Jackson, Joe, Thomas            2     3         1    3    5
# Elliot, Ezra, Joe, Josh, Leonardo               0     3         3    3    9
# Elliot, Jackson, Joe, Josh, Skyler              0     2         2    2    4
# Alec, Elliot, Jackson, Joe, Thomas              1     3         2    5    8
# Bryce, Eamonn, Jackson, Joe, Skyler             3     4         2    1    4
# Alec, Elliot, Ezra, Jackson, Thomas             1     3         1    0    4
# Ezra, Joe, Josh, Leonardo, Skyler               0     3         0    2    3
# Eamonn, Jackson, Josh, Skyler, Thomas           0     3         5    1    3
# Ezra, Jackson, Joe, Josh, Skyler                1     4         1    1    2
# Alec, Alex, Ezra, Skyler, Thomas                1     2         2    2    6
# Arrish, Bryce, Eamonn, Joe, Skyler              3     3         2    2    4
# Alec, Bryce, Eamonn, Elliot, Joe                2     4         2    2    4
# Elliot, Joe, Josh, Leonardo, Thomas             0     2         1    2    4
# Alec, Alex, Eamonn, Joe, Thomas                 0     2         3    0    3
# Alec, Alex, Eamonn, Skyler, Thomas              3     0         3    3    6
# Alec, Arrish, Ezra, Joe, Skyler                 1     3         1    4    6
# Alec, Arrish, Elliot, Joe, Thomas               0     2         3    3    8
# Bryce, Elliot, Jackson, Joe, Skyler             1     2         3    2    5
# Alex, Joe, Leonardo, Skyler, Thomas             1     2         1    3    5
# Alec, Bryce, Eamonn, Joe, Skyler                0     0         3    1    5
# Alec, Alex, Eamonn, Ezra, Joe                   0     3         1    4    6
# Alex, Eamonn, Jackson, Joe, Skyler              0     1         2    2    6
# Alec, Elliot, Ezra, Joe, Josh                   0     3         3    2    5
# Bryce, Jackson, Joe, Skyler, Thomas             1     0         0    2    2
# Arrish, Eamonn, Ezra, Jackson, Joe              2     3         3    0    4
# Alec, Eamonn, Joe, Josh, Skyler                 0     0         3    2    6
# Alec, Arrish, Bryce, Joe, Skyler                1     0         3    2    6
# Alec, Bryce, Ezra, Joe, Thomas                  1     3         1    2    6
# Alec, Bryce, Elliot, Ezra, Thomas               0     3         3    0    3
# Arrish, Jackson, Joe, Skyler, Thomas            0     2         3    2    5
# Alex, Ben, Dashiel, Jackson, Skyler             0     3         1    3    6
# Bryce, Elliot, Jackson, Skyler, Thomas          1     3         3    2    3
# Alec, Eamonn, Ezra, Joe, Josh                   0     0         2    2    5
# Arrish, Ezra, Jackson, Joe, Thomas              0     1         1    1    2
# Alec, Arrish, Joe, Skyler, Thomas               3     1         0    3    3
# Bryce, Eamonn, Elliot, Ezra, Jackson            2     2         3    0    4
# Alec, Elliot, Joe, Josh, Thomas                 1     3         1    3    5
# Arrish, Bryce, Eamonn, Ezra, Thomas             0     3         1    2    4
# Alex, Eamonn, Joe, Leonardo, Skyler             0     0         2    1    3
# Alex, Bryce, Ezra, Joe, Thomas                  0     2         3    0    3
# Arrish, Ezra, Jackson, Joe, Skyler              0     1         2    0    4
# Alec, Alex, Elliot, Joe, Thomas                 0     2         2    1    4
# Bryce, Eamonn, Elliot, Joe, Thomas              0     4         3    0    2
# Arrish, Bryce, Ezra, Skyler, Thomas             0     1         1    2    4
# Alex, Ezra, Jackson, Joe, Thomas                1     2         1    1    5
# Alex, Eamonn, Jackson, Joe, Thomas              0     2         2    1    4
# Eamonn, Jackson, Joe, Leonardo, Thomas          0     1         2    2    5
# Eamonn, Jackson, Joe, Josh, Skyler              0     2         1    3    3
# Joe, Josh, Leonardo, Skyler, Thomas             0     3         1    1    3
# Alec, Eammon, Jackson, Joe, Skyler              0     2         0    2    2
# Eamonn, Ezra, Jackson, Joe, Skyler              1     2         0    3    3
# Eamonn, Joe, Josh, Leonardo, Thomas             0     2         1    2    4
# Alex, Ezra, Joe, Josh, Skyler                   1     2         2    0    3
# Bryce, Ezra, Joe, Leonardo, Thomas              1     2         2    0    4
# Alex, Elliot, Jackson, Joe, Thomas              2     3         1    1    2
# Alex, Bryce, Elliot, Ezra, Thomas               0     0         1    1    2
# Arrish, Bryce, Ezra, Joe, Skyler                0     3         1    1    1
# Alex, Bryce, Eamonn, Elliot, Ezra               0     1         2    1    3
# Alec, Bryce, Eamonn, Skyler, Thomas             0     0         1    1    2
# Alex, Bryce, Eamonn, Ezra, Joe                  0     2         0    3    4
# Alec, Arrish, Eamonn, Jackson, Joe              1     0         1    2    3
# Alec, Arrish, Elliot, Skyler, Thomas            0     2         1    1    3
# Alec, Alex, Eamonn, Joe, Skyler                 0     2         2    1    4
# Bryce, Eamonn, Joe, Josh, Thomas                1     1         3    0    3
# Alec, Elliot, Jackson, Skyler, Thomas           0     1         2    0    2
# Arrish, Ezra, Leonardo, Skyler, Thomas          0     3         2    1    3
# Alec, Eamonn, Jackson, Skyler, Thomas           0     0         1    1    2
# Ben, Dashiel, Jackson, Joe, Josh                0     0         0    1    1
# Alec, Eamonn, Elliot, Jackson, Joe              0     0         1    1    2
# Arrish, Elliot, Ezra, Jackson, Thomas           1     1         1    0    1
# Arrish, Bryce, Eamonn, Skyler, Thomas           0     1         1    1    2
# Alec, Bryce, Joe, Skyler, Thomas                2     2         0    1    1
# Alec, Alex, Elliot, Ezra, Thomas                0     1         2    0    4
# Bryce, Ezra, Jackson, Skyler, Thomas            1     1         1    0    1
# Alec, Elliot, Ezra, Josh, Thomas                0     1         0    1    2
# Bryce, Eamonn, Elliot, Ezra, Leonardo           1     1         0    0    0
# Ezra, Josh, Leonardo, Skyler, Thomas            1     1         0    1    1
# Elliot, Ezra, Josh, Leonardo, Thomas            0     0         1    0    2
# Alec, Bryce, Elliot, Ezra, Joe                  0     0         1    0    1
# Alex, Ezra, Jackson, Skyler, Thomas             0     1         1    0    2
# Elliot, Ezra, Jackson, Leonardo, Skyler         0     0         1    0    2
# Alec, Arrish, Bryce, Eamonn, Joe                0     0         1    1    2
# Alex, Elliot, Ezra, Leonardo, Thomas            0     1         0    1    1
# Alec, Elliot, Ezra, Jackson, Joe                0     0         0    1    1
# Alex, Elliot, Ezra, Joe, Leonardo               1     1         0    2    2
# Elliot, Ezra, Josh, Skyler, Thomas              0     3         0    0    0
# Alec, Alex, Ezra, Joe, Skyler                   0     1         0    1    1
# Arrish, Bryce, Eamonn, Ezra, Skyler             0     1         1    1    2
# Eamonn, Elliot, Joe, Josh, Leonardo             0     2         1    0    1
# Alex, Eamonn, Joe, Leonardo, Thomas             1     1         1    0    1
# Arrish, Eamonn, Elliot, Joe, Leonardo           0     0         0    2    2
# Bryce, Eamonn, Ezra, Joe, Leonardo              0     1         0    1    1
# Arrish, Bryce, Elliot, Skyler, Thomas           0     0         0    1    1
# Bryce, Eammon, Joe, Skyler, Thomas              0     0         1    0    1
# Bryce, Elliot, Ezra, Jackson, Skyler            1     1         0    1    1
# Arrish, Bryce, Eamonn, Jackson, Joe             0     1         1    1    3
# Alec, Alex, Dashiel, Leonardo, Skyler           0     0         1    0    1
# Arrish, Ezra, Jackson, Skyler, Thomas           0     0         1    0    1
# Alec, Jackson, Joe, Skyler, Thomas              0     0         2    0    3
# Eamonn, Elliot, Jackson, Joe, Leonardo          0     0         1    0    1
# Alec, Alex, Elliot, Ezra, Skyler                0     0         0    1    2
# Arrish, Elliot, Joe, Leonardo, Skyler           0     1         0    0    1
# Jackson, Joe, Josh, Skyler, Thomas              0     0         1    0    0
# Alec, Ezra, Josh, Skyler, Thomas                1     1         0    1    1
# Alec, Eamonn, Elliot, Jackson, Thomas           0     1         0    1    1
# Alec, Ezra, Joe, Leonardo, Skyler               1     0         1    0    1
# Arrish, Bryce, Eamonn, Ezra, Jackson            0     1         0    1    1
# Alex, Eamonn, Joe, Skyler, Thomas               0     1         0    0    0
# Alec, Arrish, Eammon, Joe, Skyler               0     1         0    0    0
# Alec, Alex, Eamonn, Elliot, Ezra                0     0         0    0    0
# Bryce, Eamonn, Elliot, Skyler, Thomas           0     1         0    0    0
# Alex, Bryce, Elliot, Joe, Thomas                0     0         1    1    2
# Alec, Alex, Joe, Skyler, Thomas                 0     1         0    0    0
# Alec, Bryce, Ezra, Jackson, Skyler              0     1         1    0    1
# Bryce, Eamonn, Ezra, Jackson, Skyler            0     1         0    1    1
# Arrish, Eamonn, Joe, Leonardo, Skyler           0     2         0    0    0
# Bryce, Eammon, Elliot, Joe, Thomas              0     0         1    0    1
# Alec, Bryce, Ezra, Joe, Skyler                  0     1         0    0    0
# Elliot, Ezra, Joe, Josh, Thomas                 0     0         0    0    0
# Alec, Arrish, Eammon, Skyler, Thomas            0     0         0    0    0
# Alec, Bryce, Elliot, Jackson, Joe               0     1         0    0    0
# Alec, Eamonn, Jackson, Joe, Skyler              0     0         1    0    1
# Bryce, Eamonn, Joe, Skyler, Thomas              0     0         0    1    1
# Alec, Ben, Leonardo, Skyler, Thomas             1     0         1    0    0
# Alec, Ben, Jackson, Skyler, Thomas              0     1         0    0    0
# Alex, Eamonn, Elliot, Joe, Leonardo             0     0         0    0    0
# Alec, Arrish, Elliot, Jackson, Joe              0     0         0    0    0
# Alex, Ezra, Jackson, Joe, Skyler                0     0         0    0    0
# Bryce, Eammon, Elliot, Jackson, Joe             0     0         0    0    0
# Arrish, Elliot, Ezra, Joe, Thomas               0     0         0    0    0
# Elliot, Ezra, Joe, Skyler, Thomas               1     0         0    0    0
# Arrish, Bryce, Eamonn, Jackson, Thomas          0     0         0    0    0
# Ben, Ezra, Jackson, Joe, Josh                   0     0         0    0    0
# Ezra, Jackson, Joe, Leonardo, Skyler            0     0         0    0    0
# Elliot, Joe, Leonardo, Skyler, Thomas           0     0         0    0    0
# Alec, Arrish, Elliot, Jackson, Thomas           0     0         0    0    0
# Alec, Elliot, Josh, Leonardo, Thomas            0     0         0    0    0
# Jackson, Joe, Kerem, Skyler, Thomas             0     0         0    0    0
# Alec, Arrish, Elliot, Josh, Thomas              0     0         0    0    0
#
#                                          OPP FGM  OPP FGA  3PM  3PA  OPP 3PM  \
# Lineup
# Bryce, Eamonn, Jackson, Joe, Thomas           56      141   19   67       17
# Arrish, Bryce, Eamonn, Joe, Thomas            53      140   22   62       18
# Arrish, Bryce, Ezra, Joe, Thomas              28       61    8   33        2
# Alec, Arrish, Elliot, Ezra, Thomas            18       61    9   25        6
# Bryce, Elliot, Jackson, Joe, Thomas           25       61    2   10       10
# Bryce, Elliot, Ezra, Jackson, Thomas          20       40    4   19        7
# Alec, Arrish, Ezra, Joe, Thomas               14       44    4   16        1
# Bryce, Ezra, Jackson, Joe, Thomas             11       26   11   16        2
# Bryce, Eamonn, Ezra, Jackson, Joe             15       35    6   14        2
# Arrish, Bryce, Eamonn, Elliot, Joe            12       30    6   15        5
# Alec, Arrish, Eamonn, Joe, Thomas             10       23    5   11        2
# Bryce, Eamonn, Elliot, Jackson, Joe           11       17    4    6        3
# Arrish, Bryce, Elliot, Ezra, Thomas           11       16    5    7        6
# Alec, Eamonn, Jackson, Joe, Thomas             5       19    3    9        2
# Alec, Arrish, Eamonn, Elliot, Joe             11       20    2    6        2
# Alec, Eamonn, Ezra, Jackson, Joe               9       17    2   11        3
# Arrish, Bryce, Elliot, Joe, Thomas             7       17    1    2        2
# Bryce, Elliot, Ezra, Jackson, Joe              7       17    2    6        2
# Bryce, Elliot, Ezra, Josh, Thomas              7       14    1    5        0
# Arrish, Bryce, Eamonn, Ezra, Joe               4       13    3    4        2
# Eamonn, Joe, Josh, Leonardo, Skyler            4       12    2    3        2
# Bryce, Eammon, Jackson, Joe, Thomas            6       12    4   10        3
# Alec, Ezra, Joe, Josh, Thomas                  8       14    1    6        4
# Arrish, Bryce, Eamonn, Elliot, Thomas          6       11    3    9        3
# Alec, Alex, Eamonn, Elliot, Joe                3       12    1    4        1
# Alex, Bryce, Eamonn, Joe, Thomas               8       13    1    5        1
# Arrish, Eamonn, Jackson, Skyler, Thomas        7        9    2    4        4
# Alec, Elliot, Joe, Josh, Skyler                3        7    3    5        2
# Alec, Bryce, Eamonn, Joe, Thomas               3        8    0    3        0
# Alec, Alex, Ezra, Joe, Thomas                  5       11    1    1        1
# Arrish, Joe, Leonardo, Skyler, Thomas          2       11    1    2        2
# Alec, Ezra, Joe, Josh, Skyler                  4       11    1    3        2
# Bryce, Eamonn, Elliot, Jackson, Thomas         0        6    1    5        0
# Alec, Arrish, Ezra, Skyler, Thomas             6       12    1    2        4
# Arrish, Bryce, Eammon, Joe, Thomas             2       12    1    3        1
# Elliot, Jackson, Joe, Josh, Thomas             2        5    1    2        1
# Alec, Bryce, Elliot, Joe, Thomas               6       10    2    4        2
# Bryce, Ezra, Jackson, Joe, Skyler              4        9    0    3        0
# Alec, Bryce, Eamonn, Ezra, Joe                 0        5    2    4        0
# Arrish, Bryce, Eamonn, Elliot, Ezra            6        7    0    1        1
# Bryce, Eamonn, Jackson, Skyler, Thomas         3        8    2    4        1
# Arrish, Ezra, Joe, Leonardo, Thomas            3        8    1    3        0
# Alec, Arrish, Eamonn, Ezra, Joe                4        9    0    3        2
# Ezra, Joe, Josh, Leonardo, Thomas              3        4    2    5        1
# Ezra, Jackson, Joe, Josh, Thomas               3        4    2    3        2
# Alec, Alex, Elliot, Ezra, Joe                  2        5    2    5        0
# Arrish, Eamonn, Elliot, Joe, Skyler            3        8    2    6        1
# Arrish, Elliot, Joe, Leonardo, Thomas          3        7    0    1        1
# Alec, Ezra, Jackson, Joe, Thomas               2        7    0    2        0
# Arrish, Bryce, Elliot, Ezra, Joe               2        8    0    2        0
# Alec, Arrish, Eamonn, Elliot, Thomas           3        9    0    0        1
# Alex, Jackson, Joe, Skyler, Thomas             1        5    2    3        0
# Alex, Bryce, Eamonn, Elliot, Joe               1        5    1    3        0
# Arrish, Eamonn, Jackson, Joe, Thomas           2        7    0    2        1
# Elliot, Ezra, Joe, Josh, Leonardo              2        5    1    3        0
# Elliot, Jackson, Joe, Josh, Skyler             2        4    0    1        1
# Alec, Elliot, Jackson, Joe, Thomas             1        4    2    3        0
# Bryce, Eamonn, Jackson, Joe, Skyler            0        8    1    2        0
# Alec, Elliot, Ezra, Jackson, Thomas            3        6    1    4        2
# Ezra, Joe, Josh, Leonardo, Skyler              1        4    1    2        0
# Eamonn, Jackson, Josh, Skyler, Thomas          3        6    0    1        1
# Ezra, Jackson, Joe, Josh, Skyler               3        8    0    1        0
# Alec, Alex, Ezra, Skyler, Thomas               3        6    0    1        1
# Arrish, Bryce, Eamonn, Joe, Skyler             2        7    1    1        2
# Alec, Bryce, Eamonn, Elliot, Joe               1        6    0    1        0
# Elliot, Joe, Josh, Leonardo, Thomas            3        4    0    2        0
# Alec, Alex, Eamonn, Joe, Thomas                2        3    0    1        0
# Alec, Alex, Eamonn, Skyler, Thomas             3        6    0    0        1
# Alec, Arrish, Ezra, Joe, Skyler                2        6    2    3        0
# Alec, Arrish, Elliot, Joe, Thomas              2        4    0    2        1
# Bryce, Elliot, Jackson, Joe, Skyler            4        6    1    2        1
# Alex, Joe, Leonardo, Skyler, Thomas            2        5    0    1        0
# Alec, Bryce, Eamonn, Joe, Skyler               4        4    1    4        2
# Alec, Alex, Eamonn, Ezra, Joe                  1        4    0    1        0
# Alex, Eamonn, Jackson, Joe, Skyler             3        4    0    2        0
# Alec, Elliot, Ezra, Joe, Josh                  1        4    1    4        0
# Bryce, Jackson, Joe, Skyler, Thomas            3        4    1    1        1
# Arrish, Eamonn, Ezra, Jackson, Joe             3        7    0    3        0
# Alec, Eamonn, Joe, Josh, Skyler                2        2    0    1        1
# Alec, Arrish, Bryce, Joe, Skyler               3        5    0    3        1
# Alec, Bryce, Ezra, Joe, Thomas                 2        6    0    2        1
# Alec, Bryce, Elliot, Ezra, Thomas              2        4    0    3        0
# Arrish, Jackson, Joe, Skyler, Thomas           1        2    0    2        0
# Alex, Ben, Dashiel, Jackson, Skyler            0        3    2    4        0
# Bryce, Elliot, Jackson, Skyler, Thomas         1        5    1    2        1
# Alec, Eamonn, Ezra, Joe, Josh                  2        2    1    3        0
# Arrish, Ezra, Jackson, Joe, Thomas             3        4    1    2        1
# Alec, Arrish, Joe, Skyler, Thomas              1        6    0    0        0
# Bryce, Eamonn, Elliot, Ezra, Jackson           3        6    0    1        1
# Alec, Elliot, Joe, Josh, Thomas                0        3    1    3        0
# Arrish, Bryce, Eamonn, Ezra, Thomas            1        4    2    3        0
# Alex, Eamonn, Joe, Leonardo, Skyler            4        4    0    1        1
# Alex, Bryce, Ezra, Joe, Thomas                 3        5    0    0        0
# Arrish, Ezra, Jackson, Joe, Skyler             2        3    0    0        0
# Alec, Alex, Elliot, Joe, Thomas                2        4    0    2        2
# Bryce, Eamonn, Elliot, Joe, Thomas             1        5    0    2        0
# Arrish, Bryce, Ezra, Skyler, Thomas            1        2    1    2        0
# Alex, Ezra, Jackson, Joe, Thomas               1        4    1    4        1
# Alex, Eamonn, Jackson, Joe, Thomas             2        4    0    1        2
# Eamonn, Jackson, Joe, Leonardo, Thomas         2        3    0    0        0
# Eamonn, Jackson, Joe, Josh, Skyler             2        3    0    0        1
# Joe, Josh, Leonardo, Skyler, Thomas            2        5    0    0        1
# Alec, Eammon, Jackson, Joe, Skyler             1        3    2    2        1
# Eamonn, Ezra, Jackson, Joe, Skyler             1        3    1    1        0
# Eamonn, Joe, Josh, Leonardo, Thomas            1        3    1    2        0
# Alex, Ezra, Joe, Josh, Skyler                  1        3    0    2        1
# Bryce, Ezra, Joe, Leonardo, Thomas             1        4    0    2        0
# Alex, Elliot, Jackson, Joe, Thomas             1        4    1    2        0
# Alex, Bryce, Elliot, Ezra, Thomas              3        3    0    1        0
# Arrish, Bryce, Ezra, Joe, Skyler               0        3    0    0        0
# Alex, Bryce, Eamonn, Elliot, Ezra              3        4    0    1        2
# Alec, Bryce, Eamonn, Skyler, Thomas            2        2    0    0        0
# Alex, Bryce, Eamonn, Ezra, Joe                 1        3    1    2        0
# Alec, Arrish, Eamonn, Jackson, Joe             2        3    1    1        0
# Alec, Arrish, Elliot, Skyler, Thomas           1        2    0    0        0
# Alec, Alex, Eamonn, Joe, Skyler                1        3    0    2        1
# Bryce, Eamonn, Joe, Josh, Thomas               1        3    0    3        0
# Alec, Elliot, Jackson, Skyler, Thomas          0        0    0    1        0
# Arrish, Ezra, Leonardo, Skyler, Thomas         0        3    0    1        0
# Alec, Eamonn, Jackson, Skyler, Thomas          2        2    1    2        0
# Ben, Dashiel, Jackson, Joe, Josh               1        1    0    0        0
# Alec, Eamonn, Elliot, Jackson, Joe             2        2    0    1        1
# Arrish, Elliot, Ezra, Jackson, Thomas          1        3    0    0        1
# Arrish, Bryce, Eamonn, Skyler, Thomas          1        2    0    1        0
# Alec, Bryce, Joe, Skyler, Thomas               3        7    0    0        0
# Alec, Alex, Elliot, Ezra, Thomas               0        1    0    2        0
# Bryce, Ezra, Jackson, Skyler, Thomas           0        2    0    0        0
# Alec, Elliot, Ezra, Josh, Thomas               2        2    1    2        2
# Bryce, Eamonn, Elliot, Ezra, Leonardo          1        3    0    0        0
# Ezra, Josh, Leonardo, Skyler, Thomas           0        2    1    1        0
# Elliot, Ezra, Josh, Leonardo, Thomas           0        0    0    2        0
# Alec, Bryce, Elliot, Ezra, Joe                 1        1    0    1        0
# Alex, Ezra, Jackson, Skyler, Thomas            0        2    0    0        0
# Elliot, Ezra, Jackson, Leonardo, Skyler        1        1    0    1        1
# Alec, Arrish, Bryce, Eamonn, Joe               0        0    0    0        0
# Alex, Elliot, Ezra, Leonardo, Thomas           0        1    0    0        0
# Alec, Elliot, Ezra, Jackson, Joe               2        2    0    0        0
# Alex, Elliot, Ezra, Joe, Leonardo              0        2    0    0        0
# Elliot, Ezra, Josh, Skyler, Thomas             1        4    0    0        0
# Alec, Alex, Ezra, Joe, Skyler                  1        2    1    1        0
# Arrish, Bryce, Eamonn, Ezra, Skyler            0        1    0    0        0
# Eamonn, Elliot, Joe, Josh, Leonardo            0        2    0    1        0
# Alex, Eamonn, Joe, Leonardo, Thomas            1        3    0    1        0
# Arrish, Eamonn, Elliot, Joe, Leonardo          1        1    0    0        0
# Bryce, Eamonn, Ezra, Joe, Leonardo             0        1    0    0        0
# Arrish, Bryce, Elliot, Skyler, Thomas          1        1    0    0        1
# Bryce, Eammon, Joe, Skyler, Thomas             2        2    0    1        0
# Bryce, Elliot, Ezra, Jackson, Skyler           0        2    0    0        0
# Arrish, Bryce, Eamonn, Jackson, Joe            0        1    1    2        0
# Alec, Alex, Dashiel, Leonardo, Skyler          2        2    0    1        2
# Arrish, Ezra, Jackson, Skyler, Thomas          1        1    0    0        1
# Alec, Jackson, Joe, Skyler, Thomas             1        1    0    2        0
# Eamonn, Elliot, Jackson, Joe, Leonardo         0        0    0    1        0
# Alec, Alex, Elliot, Ezra, Skyler               1        1    0    1        1
# Arrish, Elliot, Joe, Leonardo, Skyler          0        1    0    0        0
# Jackson, Joe, Josh, Skyler, Thomas             1        1    0    0        1
# Alec, Ezra, Josh, Skyler, Thomas               0        1    1    1        0
# Alec, Eamonn, Elliot, Jackson, Thomas          0        1    1    1        0
# Alec, Ezra, Joe, Leonardo, Skyler              1        2    0    0        1
# Arrish, Bryce, Eamonn, Ezra, Jackson           0        1    0    0        0
# Alex, Eamonn, Joe, Skyler, Thomas              1        1    0    0        0
# Alec, Arrish, Eammon, Joe, Skyler              0        1    0    0        0
# Alec, Alex, Eamonn, Elliot, Ezra               0        0    0    0        0
# Bryce, Eamonn, Elliot, Skyler, Thomas          0        1    0    0        0
# Alex, Bryce, Elliot, Joe, Thomas               0        0    1    2        0
# Alec, Alex, Joe, Skyler, Thomas                0        1    0    0        0
# Alec, Bryce, Ezra, Jackson, Skyler             0        1    0    1        0
# Bryce, Eamonn, Ezra, Jackson, Skyler           0        0    1    1        0
# Arrish, Eamonn, Joe, Leonardo, Skyler          0        2    0    0        0
# Bryce, Eammon, Elliot, Joe, Thomas             1        1    0    1        0
# Alec, Bryce, Ezra, Joe, Skyler                 0        1    0    0        0
# Elliot, Ezra, Joe, Josh, Thomas                1        1    0    0        0
# Alec, Arrish, Eammon, Skyler, Thomas           0        0    0    0        0
# Alec, Bryce, Elliot, Jackson, Joe              0        1    0    0        0
# Alec, Eamonn, Jackson, Joe, Skyler             0        0    0    1        0
# Bryce, Eamonn, Joe, Skyler, Thomas             0        0    0    0        0
# Alec, Ben, Leonardo, Skyler, Thomas            0        1    0    0        0
# Alec, Ben, Jackson, Skyler, Thomas             0        0    0    0        0
# Alex, Eamonn, Elliot, Joe, Leonardo            0        0    0    0        0
# Alec, Arrish, Elliot, Jackson, Joe             0        0    0    0        0
# Alex, Ezra, Jackson, Joe, Skyler               1        1    0    0        0
# Bryce, Eammon, Elliot, Jackson, Joe            0        0    0    0        0
# Arrish, Elliot, Ezra, Joe, Thomas              0        0    0    0        0
# Elliot, Ezra, Joe, Skyler, Thomas              0        1    0    0        0
# Arrish, Bryce, Eamonn, Jackson, Thomas         0        1    0    0        0
# Ben, Ezra, Jackson, Joe, Josh                  0        0    0    0        0
# Ezra, Jackson, Joe, Leonardo, Skyler           0        0    0    0        0
# Elliot, Joe, Leonardo, Skyler, Thomas          0        0    0    0        0
# Alec, Arrish, Elliot, Jackson, Thomas          0        0    0    0        0
# Alec, Elliot, Josh, Leonardo, Thomas           0        0    0    0        0
# Jackson, Joe, Kerem, Skyler, Thomas            0        0    0    0        0
# Alec, Arrish, Elliot, Josh, Thomas             0        0    0    0        0
#
#                                          OPP 3PA  FTM  OPP FTM  FTA  OPP FTA  \
# Lineup
# Bryce, Eamonn, Jackson, Joe, Thomas           51   25       53   32       65
# Arrish, Bryce, Eamonn, Joe, Thomas            52   32       29   37       39
# Arrish, Bryce, Ezra, Joe, Thomas              15   16        9   21       12
# Alec, Arrish, Elliot, Ezra, Thomas            24    3        5    4        9
# Bryce, Elliot, Jackson, Joe, Thomas           29   20       13   27       19
# Bryce, Elliot, Ezra, Jackson, Thomas          14    6        3    8        6
# Alec, Arrish, Ezra, Joe, Thomas               13    9        0   10        1
# Bryce, Ezra, Jackson, Joe, Thomas              5    6        6    7        8
# Bryce, Eamonn, Ezra, Jackson, Joe              9    7        9    9       13
# Arrish, Bryce, Eamonn, Elliot, Joe            11   10        0   12        1
# Alec, Arrish, Eamonn, Joe, Thomas              7    6        8    9        9
# Bryce, Eamonn, Elliot, Jackson, Joe            7    6       10    9       12
# Arrish, Bryce, Elliot, Ezra, Thomas            8    0        1    0        3
# Alec, Eamonn, Jackson, Joe, Thomas             8    5        3    7        5
# Alec, Arrish, Eamonn, Elliot, Joe              5    1        4    1        4
# ...
# Arrish, Bryce, Eamonn, Jackson, Thomas     0.0    0.0       0.0       0.0
# Ben, Ezra, Jackson, Joe, Josh              0.0    0.0       0.0       0.0
# Ezra, Jackson, Joe, Leonardo, Skyler       0.0    0.0       0.0       0.0
# Elliot, Joe, Leonardo, Skyler, Thomas      0.0    0.0       0.0       0.0
# Alec, Arrish, Elliot, Jackson, Thomas      0.0    0.0       0.0       0.0
# Alec, Elliot, Josh, Leonardo, Thomas       0.0    0.0       0.0       0.0
# Jackson, Joe, Kerem, Skyler, Thomas        0.0    0.0       0.0       0.0
# Alec, Arrish, Elliot, Josh, Thomas         0.0    0.0       0.0       0.0
#
#                                          OPP RB%    TO%  OPP TO%  POSS PER40
# Lineup
# Bryce, Eamonn, Jackson, Joe, Thomas         52.4   17.2     19.1       64.10
# Arrish, Bryce, Eamonn, Joe, Thomas          47.0   21.2     14.0       67.91
# Arrish, Bryce, Ezra, Joe, Thomas            49.4   21.0     19.9       61.73
# Alec, Arrish, Elliot, Ezra, Thomas          45.2   22.7     18.2       66.37
# Bryce, Elliot, Jackson, Joe, Thomas         50.0   26.1     17.8       69.00
# Bryce, Elliot, Ezra, Jackson, Thomas        57.4   26.3     21.0       72.65
# Alec, Arrish, Ezra, Joe, Thomas             48.2   23.5     13.2       65.32
# Bryce, Ezra, Jackson, Joe, Thomas           44.0   13.3     23.5       66.25
# Bryce, Eamonn, Ezra, Jackson, Joe           50.0   27.4     13.4       71.16
# Arrish, Bryce, Eamonn, Elliot, Joe          46.0   16.1      3.9       67.00
# Alec, Arrish, Eamonn, Joe, Thomas           53.1   17.4     28.8       69.58
# Bryce, Eamonn, Elliot, Jackson, Joe         60.0   32.1     24.7       77.48
# Arrish, Bryce, Elliot, Ezra, Thomas         70.0   16.4     27.0       59.08
# Alec, Eamonn, Jackson, Joe, Thomas          43.3   17.3     18.0       76.10
# Alec, Arrish, Eamonn, Elliot, Joe           41.2   43.7     13.7       68.70
# Alec, Eamonn, Ezra, Jackson, Joe            50.0   15.4     26.9       69.67
# Arrish, Bryce, Elliot, Joe, Thomas          47.1   18.5     11.3       60.39
# Bryce, Elliot, Ezra, Jackson, Joe           47.6   19.5      5.8       59.08
# Bryce, Elliot, Ezra, Josh, Thomas           47.1   17.9     28.9       66.31
# Arrish, Bryce, Eamonn, Ezra, Joe            38.9   18.6     18.4       64.04
# Eamonn, Joe, Josh, Leonardo, Skyler         35.7   13.9     26.4       58.88
# Bryce, Eammon, Jackson, Joe, Thomas         46.7   17.4      6.3       71.72
# Alec, Ezra, Joe, Josh, Thomas               52.9   16.2      7.8       53.76
# Arrish, Bryce, Eamonn, Elliot, Thomas       56.2    6.8     23.5       66.74
# Alec, Alex, Eamonn, Elliot, Joe             46.7   28.5     16.2       67.87
# Alex, Bryce, Eamonn, Joe, Thomas            69.2   16.9     24.3       59.63
# Arrish, Eamonn, Jackson, Skyler, Thomas     40.0   31.2     18.9       52.24
# Alec, Elliot, Joe, Josh, Skyler             41.7   22.1     38.7       50.58
# Alec, Bryce, Eamonn, Joe, Thomas            50.0   17.2     17.2       67.88
# Alec, Alex, Ezra, Joe, Thomas               66.7   38.3     34.7       61.74
# Arrish, Joe, Leonardo, Skyler, Thomas       57.1   21.4     12.5       59.65
# Alec, Ezra, Joe, Josh, Skyler               36.4   13.4      0.0       48.85
# Bryce, Eamonn, Elliot, Jackson, Thomas      43.8    9.9      0.0       66.59
# Alec, Arrish, Ezra, Skyler, Thomas          60.0   13.2      0.0       50.71
# Arrish, Bryce, Eammon, Joe, Thomas          58.3   16.8     26.0       40.58
# Elliot, Jackson, Joe, Josh, Thomas          42.9   32.0     26.8       65.18
# Alec, Bryce, Elliot, Joe, Thomas            70.0    0.0     20.8       86.00
# Bryce, Ezra, Jackson, Joe, Skyler           46.7   31.2     11.0       67.76
# Alec, Bryce, Eamonn, Ezra, Joe              30.0   23.2     44.1       61.17
# Arrish, Bryce, Eamonn, Elliot, Ezra         40.0   33.1     21.1       68.18
# Bryce, Eamonn, Jackson, Skyler, Thomas      55.6   15.1     29.8       53.55
# Arrish, Ezra, Joe, Leonardo, Thomas         44.4   55.9     28.0       72.79
# Alec, Arrish, Eamonn, Ezra, Joe             50.0   32.0     10.1       76.23
# Ezra, Joe, Josh, Leonardo, Thomas           50.0   37.0     52.1       66.60
# Ezra, Jackson, Joe, Josh, Thomas            66.7    0.0     15.4       65.54
# Alec, Alex, Elliot, Ezra, Joe               37.5    0.0     42.0       66.96
# Arrish, Eamonn, Elliot, Joe, Skyler         45.4   11.7     12.3       77.21
# Arrish, Elliot, Joe, Leonardo, Thomas       77.8   24.4     26.8       74.64
# Alec, Ezra, Jackson, Joe, Thomas            55.6    0.0     15.1       43.97
# Arrish, Bryce, Elliot, Ezra, Joe            60.0   30.3      0.0       61.44
# Alec, Arrish, Eamonn, Elliot, Thomas        45.4   20.0      0.0       46.98
# Alex, Jackson, Joe, Skyler, Thomas          40.0   29.8     30.3       63.50
# Alex, Bryce, Eamonn, Elliot, Joe            42.9   52.1     32.4       75.54
# Arrish, Eamonn, Jackson, Joe, Thomas        42.9   32.4     14.2       61.06
# Elliot, Ezra, Joe, Josh, Leonardo           33.3    0.0      0.0       57.36
# Elliot, Jackson, Joe, Josh, Skyler          40.0   56.0     34.7       71.13
# Alec, Elliot, Jackson, Joe, Thomas          42.9    0.0     33.0       66.92
# Bryce, Eamonn, Jackson, Joe, Skyler         50.0   41.7      0.0       49.44
# Alec, Elliot, Ezra, Jackson, Thomas         25.0   24.8     15.1       41.71
# Ezra, Joe, Josh, Leonardo, Skyler            0.0   58.7     17.7       54.48
# Eamonn, Jackson, Josh, Skyler, Thomas       62.5   23.5      0.0       45.67
# Ezra, Jackson, Joe, Josh, Skyler            33.3   60.6      0.0       71.40
# Alec, Alex, Ezra, Skyler, Thomas            42.9   20.8      0.0       53.33
# Arrish, Bryce, Eamonn, Joe, Skyler          62.5   17.7     20.8       63.01
# Alec, Bryce, Eamonn, Elliot, Joe            50.0    0.0     19.2       52.54
# Elliot, Joe, Josh, Leonardo, Thomas         25.0   26.0      0.0       43.07
# Alec, Alex, Eamonn, Joe, Thomas             60.0   30.8     35.4       73.12
# Alec, Alex, Eamonn, Skyler, Thomas         100.0    0.0     48.5       65.52
# Alec, Arrish, Ezra, Joe, Skyler             28.6    0.0      0.0       59.50
# Alec, Arrish, Elliot, Joe, Thomas           42.9   14.9     44.6       78.67
# Bryce, Elliot, Jackson, Joe, Skyler         66.7    0.0      0.0       62.36
# Alex, Joe, Leonardo, Skyler, Thomas         40.0    0.0      0.0       46.78
# Alec, Bryce, Eamonn, Joe, Skyler            75.0    0.0      0.0       57.66
# Alec, Alex, Eamonn, Ezra, Joe               16.7    0.0     16.5       63.84
# Alex, Eamonn, Jackson, Joe, Skyler          40.0    0.0     20.8       69.85
# Alec, Elliot, Ezra, Joe, Josh               50.0    0.0      0.0       61.28
# Bryce, Jackson, Joe, Skyler, Thomas        100.0   42.7     26.0       60.13
# Arrish, Eamonn, Ezra, Jackson, Joe          55.6   21.4     16.2       61.11
# Alec, Eamonn, Joe, Josh, Skyler             60.0    0.0     34.7       78.92
# Alec, Arrish, Bryce, Joe, Skyler            80.0    0.0     34.7       63.65
# Alec, Bryce, Ezra, Joe, Thomas              25.0    0.0      0.0       50.79
# Alec, Bryce, Elliot, Ezra, Thomas           50.0    0.0     17.7       75.11
# Arrish, Jackson, Joe, Skyler, Thomas        60.0    0.0     46.2       73.73
# Alex, Ben, Dashiel, Jackson, Skyler         16.7    0.0      0.0       54.21
# Bryce, Elliot, Jackson, Skyler, Thomas      57.1    0.0     17.7       59.25
# Alec, Eamonn, Ezra, Joe, Josh               66.7    0.0     46.9       55.19
# Arrish, Ezra, Jackson, Joe, Thomas          50.0   24.1      0.0       59.96
# Alec, Arrish, Joe, Skyler, Thomas           75.0    0.0      0.0       42.67
# Bryce, Eamonn, Elliot, Ezra, Jackson        62.5   26.0     19.2       56.89
# Alec, Elliot, Joe, Josh, Thomas             33.3    0.0      0.0       57.60
# Arrish, Bryce, Eamonn, Ezra, Thomas         20.0   52.1      0.0       88.05
# Alex, Eamonn, Joe, Leonardo, Skyler        100.0    0.0      0.0       44.03
# Alex, Bryce, Ezra, Joe, Thomas              60.0    0.0      0.0       71.21
# Arrish, Ezra, Jackson, Joe, Skyler          40.0   34.7     26.0       44.88
# Alec, Alex, Elliot, Joe, Thomas             40.0    0.0      0.0       45.18
# Bryce, Eamonn, Elliot, Joe, Thomas          37.5   32.0     15.1       99.48
# Arrish, Bryce, Ezra, Skyler, Thomas         33.3   26.0     30.3       61.85
# Alex, Ezra, Jackson, Joe, Thomas            28.6   26.8      0.0       61.65
# Alex, Eamonn, Jackson, Joe, Thomas          40.0    0.0      0.0       47.67
# Eamonn, Jackson, Joe, Leonardo, Thomas      50.0   19.2     41.7       88.27
# Eamonn, Jackson, Joe, Josh, Skyler          33.3    0.0      0.0       56.61
# Joe, Josh, Leonardo, Skyler, Thomas         20.0   62.5      0.0       84.71
# Alec, Eammon, Jackson, Joe, Skyler           0.0   52.1      0.0       68.27
# Eamonn, Ezra, Jackson, Joe, Skyler          33.3    0.0      0.0       52.76
# Eamonn, Joe, Josh, Leonardo, Thomas         25.0    0.0      0.0       53.17
# Alex, Ezra, Joe, Josh, Skyler               50.0   30.3      0.0       61.44
# Bryce, Ezra, Joe, Leonardo, Thomas          42.9    0.0      0.0       51.44
# Alex, Elliot, Jackson, Joe, Thomas          50.0   34.7      0.0       54.00
# Alex, Bryce, Elliot, Ezra, Thomas          100.0   34.7      0.0       56.20
# Arrish, Bryce, Ezra, Joe, Skyler            25.0   31.4     23.5       63.74
# Alex, Bryce, Eamonn, Elliot, Ezra           66.7   26.0      0.0       76.80
# Alec, Bryce, Eamonn, Skyler, Thomas        100.0    0.0     34.7       56.23
# Alex, Bryce, Eamonn, Ezra, Joe               0.0    0.0      0.0       76.41
# Alec, Arrish, Eamonn, Jackson, Joe         100.0   26.0     34.7       79.45
# Alec, Arrish, Elliot, Skyler, Thomas        25.0    0.0      0.0       41.89
# Alec, Alex, Eamonn, Joe, Skyler             40.0    0.0     26.0       64.00
# Bryce, Eamonn, Joe, Josh, Thomas            66.7    0.0      0.0       69.12
# Alec, Elliot, Jackson, Skyler, Thomas       66.7    0.0     37.7       69.85
# Arrish, Ezra, Leonardo, Skyler, Thomas      40.0    0.0      0.0       72.76
# Alec, Eamonn, Jackson, Skyler, Thomas      100.0    0.0     21.9       48.51
# Ben, Dashiel, Jackson, Joe, Josh             0.0   52.1     52.1       49.55
# Alec, Eamonn, Elliot, Jackson, Joe         100.0    0.0      0.0       72.92
# Arrish, Elliot, Ezra, Jackson, Thomas       66.7   36.2     34.7       74.56
# Arrish, Bryce, Eamonn, Skyler, Thomas       50.0    0.0      0.0       54.21
# Alec, Bryce, Joe, Skyler, Thomas            50.0    0.0     26.4       74.81
# Alec, Alex, Elliot, Ezra, Thomas            40.0   34.7     52.1       83.28
# Bryce, Ezra, Jackson, Skyler, Thomas        66.7    0.0      0.0       53.48
# Alec, Elliot, Ezra, Josh, Thomas             0.0   36.2      0.0       81.92
# Bryce, Eamonn, Elliot, Ezra, Leonardo       50.0  104.2      0.0       28.80
# Ezra, Josh, Leonardo, Skyler, Thomas        50.0    0.0      0.0       30.72
# Elliot, Ezra, Josh, Leonardo, Thomas        50.0   52.1    104.2       66.78
# Alec, Bryce, Elliot, Ezra, Joe             100.0    0.0      0.0       34.39
# Alex, Ezra, Jackson, Skyler, Thomas         33.3    0.0      0.0       49.52
# Elliot, Ezra, Jackson, Leonardo, Skyler    100.0   34.7     52.1      103.16
# Alec, Arrish, Bryce, Eamonn, Joe           100.0    0.0    104.2       69.82
# Alex, Elliot, Ezra, Leonardo, Thomas         0.0    0.0      0.0       50.27
# Alec, Elliot, Ezra, Jackson, Joe             0.0   69.4      0.0      108.00
# Alex, Elliot, Ezra, Joe, Leonardo           50.0    0.0      0.0       73.14
# Elliot, Ezra, Josh, Skyler, Thomas           0.0   44.9      0.0       86.21
# Alec, Alex, Ezra, Joe, Skyler                0.0    0.0      0.0       38.40
# Arrish, Bryce, Eamonn, Ezra, Skyler         50.0    0.0      0.0       78.10
# Eamonn, Elliot, Joe, Josh, Leonardo         33.3    0.0      0.0       40.42
# Alex, Eamonn, Joe, Leonardo, Thomas         66.7   52.1      0.0       80.84
# Arrish, Eamonn, Elliot, Joe, Leonardo        0.0    0.0      0.0       85.33
# Bryce, Eamonn, Ezra, Joe, Leonardo           0.0    0.0      0.0       43.47
# Arrish, Bryce, Elliot, Skyler, Thomas        0.0    0.0      0.0       44.31
# Bryce, Eammon, Joe, Skyler, Thomas         100.0    0.0      0.0       44.31
# Bryce, Elliot, Ezra, Jackson, Skyler        50.0    0.0      0.0       45.18
# Arrish, Bryce, Eamonn, Jackson, Joe         33.3    0.0     52.1       96.00
# Alec, Alex, Dashiel, Leonardo, Skyler      100.0    0.0      0.0       48.00
# Arrish, Ezra, Jackson, Skyler, Thomas       50.0  104.2      0.0       50.09
# Alec, Jackson, Joe, Skyler, Thomas          66.7    0.0      0.0      102.40
# Eamonn, Elliot, Jackson, Joe, Leonardo     100.0    0.0      0.0       52.36
# Alec, Alex, Elliot, Ezra, Skyler             0.0    0.0      0.0       54.86
# Arrish, Elliot, Joe, Leonardo, Skyler        0.0    0.0      0.0       56.32
# Jackson, Joe, Josh, Skyler, Thomas         100.0    0.0      0.0       57.93
# Alec, Ezra, Josh, Skyler, Thomas            50.0    0.0      0.0       65.83
# Alec, Eamonn, Elliot, Jackson, Thomas        0.0    0.0      0.0       69.82
# Alec, Ezra, Joe, Leonardo, Skyler          100.0    0.0      0.0       72.00
# Arrish, Bryce, Eamonn, Ezra, Jackson         0.0    0.0      0.0       72.00
# Alex, Eamonn, Joe, Skyler, Thomas            0.0  104.2     42.7       79.45
# Alec, Arrish, Eammon, Joe, Skyler            0.0    0.0      0.0        0.00
# Alec, Alex, Eamonn, Elliot, Ezra             0.0    0.0      0.0        0.00
# Bryce, Eamonn, Elliot, Skyler, Thomas        0.0    0.0      0.0        0.00
# Alex, Bryce, Elliot, Joe, Thomas           100.0    0.0      0.0      170.67
# Alec, Alex, Joe, Skyler, Thomas              0.0    0.0      0.0       77.98
# Alec, Bryce, Ezra, Jackson, Skyler          50.0    0.0      0.0       96.00
# Bryce, Eamonn, Ezra, Jackson, Skyler         0.0    0.0      0.0      100.17
# Arrish, Eamonn, Joe, Leonardo, Skyler        0.0    0.0      0.0       92.16
# Bryce, Eammon, Elliot, Joe, Thomas         100.0    0.0      0.0      115.20
# Alec, Bryce, Ezra, Joe, Skyler               0.0  104.2      0.0      128.00
# Elliot, Ezra, Joe, Josh, Thomas              0.0    0.0      0.0        0.00
# Alec, Arrish, Eammon, Skyler, Thomas         0.0  104.2      0.0      135.53
# Alec, Bryce, Elliot, Jackson, Joe            0.0    0.0      0.0      119.27
# Alec, Eamonn, Jackson, Joe, Skyler         100.0    0.0      0.0      164.57
# Bryce, Eamonn, Joe, Skyler, Thomas           0.0    0.0      0.0      177.23
# Alec, Ben, Leonardo, Skyler, Thomas        100.0    0.0      0.0        0.00
# Alec, Ben, Jackson, Skyler, Thomas           0.0    0.0      0.0      168.96
# Alex, Eamonn, Elliot, Joe, Leonardo          0.0    0.0    104.2        0.00
# Alec, Arrish, Elliot, Jackson, Joe           0.0    0.0      0.0        0.00
# Alex, Ezra, Jackson, Joe, Skyler             0.0    0.0      0.0        0.00
# Bryce, Eammon, Elliot, Jackson, Joe          0.0    0.0      0.0      202.75
# Arrish, Elliot, Ezra, Joe, Thomas            0.0    0.0      0.0      608.26
# Elliot, Ezra, Joe, Skyler, Thomas          100.0    0.0      0.0        0.00
# Arrish, Bryce, Eamonn, Jackson, Thomas       0.0    0.0      0.0        0.00
# Ben, Ezra, Jackson, Joe, Josh                0.0    0.0      0.0        0.00
# Ezra, Jackson, Joe, Leonardo, Skyler         0.0    0.0      0.0        0.00
# Elliot, Joe, Leonardo, Skyler, Thomas        0.0    0.0      0.0        0.00
# Alec, Arrish, Elliot, Jackson, Thomas        0.0    0.0      0.0        0.00
# Alec, Elliot, Josh, Leonardo, Thomas         0.0    0.0      0.0        0.00
# Jackson, Joe, Kerem, Skyler, Thomas          0.0    0.0      0.0        0.00
# Alec, Arrish, Elliot, Josh, Thomas           0.0    0.0      0.0        0.00

# %%
game_advanced = pd.concat([game_helper( current ), 
                           total_advanced( current, uaa=True ), 
                           total_advanced( current )])
game_advanced.index = list(game_advanced.index)[0:len(game_advanced.index)-2] + ["UAA Total", "Total"]

game_advanced

# %%
games = []
for date in pd.unique(current.Date):
    opp_game = pbp_helper( current[(current.Date == date)] )
    opp_game['Opponent'] = current[(current.Date == date)].Opponent.values[0]
    games.append(opp_game)
    
games = pd.concat(games)

games['Lineup'] = games.index
games.Lineup = games.Lineup.apply(lambda l : ", ".join([i.split(" ")[0] for i in l.split(", ")]))

games = games.set_index('Lineup')

games
