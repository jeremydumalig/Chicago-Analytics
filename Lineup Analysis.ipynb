# %%
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_colwidth', None)

# %%
lineups = pd.read_csv("lineups22.csv").iloc[:, 1:]
plays = pd.read_csv("uchicago22.csv").iloc[:, 1:]

# %%
def points(action):
    if "made 3" in action:
        return 3
    elif "made free" in action:
        return 1
    elif "made" in action:
        return 2
    else:
        return 0

# %%
[i for i in plays.Action if "Block" in i]
# Out:
# ['Block by HOPKINS,BRYCE',
#  'Block by PRICE,ADRIAN',
#  'Block by ROMERO,EDGAR',
#  'Block by HOPKINS,BRYCE',
#  'Block by PASCHAL,ELLIOT',
#  'Block by EDO,LEONARDO',
#  'Block by PASCHAL,ELLIOT',
#  'Block by COWARD,CEDRIC',
#  'Block by PASCHAL,ELLIOT',
#  'Block by COWARD,CEDRIC',
#  'Block by PASCHAL,ELLIOT',
#  'Block by PASCHAL,ELLIOT',
#  'Block by MUNSON,ZACH',
#  'Block by KUROWSKI,THOMAS',
#  'Block by PASCHAL,ELLIOT',
#  'Block by KUROWSKI,THOMAS',
#  'Block by KUROWSKI,THOMAS',
#  'Block by PIOTROWSKI,JACKSON',
#  'Block by MCSLARROW,PAUL',
#  'Block by COWARD,CEDRIC',
#  'Block by HOFFMAN,MASON',
#  'Block by HOPKINS,BRYCE',
#  'Block by KUROWSKI,THOMAS',
#  'Block by PASCHAL,ELLIOT',
#  'Block by PASCHAL,ELLIOT',
#  'Block by KUROWSKI,THOMAS',
#  'Block by EDO,LEONARDO',
#  'Block by MUNSON,ZACH',
#  'Block by CONSIDINE,ELI',
#  'Block by ALIOTH,CADE',
#  'Block by SCHIAVELLO,NICK',
#  'Block by ADOM,NYAMEYE',
#  'Block by EDO,LEONARDO',
#  'Block by BRYAN,ALEC',
#  'Block by HOPKINS,BRYCE',
#  'Block by ADOM,NYAMEYE',
#  'Block by KUROWSKI,THOMAS',
#  'Block by MARTIN,RYAN',
#  'Block by HOPKINS,BRYCE',
#  'Block by REALE,OTIS',
#  'Block by SCHMITZ,CALVIN',
#  'Block by LERITZ,MATTHEW',
#  'Block by HOPKINS,BRYCE',
#  'Block by SCHNEIDER,EVAN',
#  'Block by BHANDAL,ARRISH',
#  'Block by BHANDAL,ARRISH',
#  'Block by SCHROECKENTHALER,JAKE',
#  'Block by MARTIN,RYAN',
#  'Block by HARTJES,ELI',
#  'Block by KUROWSKI,THOMAS',
#  'Block by BHANDAL,ARRISH',
#  'Block by BHANDAL,ARRISH',
#  'Block by PASCHAL,ELLIOT',
#  'Block by HOPKINS,BRYCE',
#  'Block by MARTIN,RYAN',
#  'Block by BECKMAN,BRANDON',
#  'Block by PIOTROWSKI,JACKSON',
#  'Block by BHANDAL,ARRISH',
#  'Block by MOOS,EZRA',
#  'Block by BHANDAL,ARRISH',
#  'Block by PIOTROWSKI,JACKSON',
#  'Block by UADIALE,FELIX',
#  'Block by UADIALE,FELIX',
#  'Block by RASNICK,MYLES',
#  'Block by HOPKINS,BRYCE',
#  'Block by RASNICK,MYLES',
#  'Block by UADIALE,FELIX',
#  'Block by PIOTROWSKI,JACKSON',
#  'Block by CLIFTON,NICHOLAS',
#  'Block by PEREZ,B AMABILINO',
#  'Block by BRYAN,ALEC',
#  'Block by BRYAN,ALEC',
#  'Block by PRICE,TC',
#  'Block by BHANDAL,ARRISH',
#  'Block by GANG,ROSS',
#  'Block by GANG,ROSS',
#  'Block by BHANDAL,ARRISH',
#  'Block by BRYAN,ALEC',
#  'Block by SHANAHAN,LOGAN',
#  'Block by MARTENS,CALE',
#  'Block by SHANAHAN,LOGAN',
#  'Block by SHANAHAN,LOGAN',
#  'Block by PIOTROWSKI,JACKSON',
#  'Block by EDO,LEONARDO',
#  'Block by EDO,LEONARDO',
#  'Block by EDO,LEONARDO',
#  'Block by HAGERTY,NOLAN',
#  'Block by HOPKINS,BRYCE',
#  'Block by MARTIN,RYAN',
#  'Block by BECKMAN,BRANDON',
#  'Block by AKINA,KAWIKA',
#  'Block by KUROWSKI,THOMAS',
#  'Block by HOPKINS,BRYCE',
#  'Block by KORNAKER,GRIFFIN',
#  'Block by NEWTON,RYAN',
#  'Block by PASCHAL,ELLIOT',
#  'Block by FRILLING,COLE',
#  'Block by HOPKINS,BRYCE',
#  'Block by SAX,KEVIN',
#  'Block by OBERMAN,SEAN',
#  'Block by HOPKINS,BRYCE',
#  'Block by HOPKINS,BRYCE',
#  'Block by EDO,LEONARDO',
#  'Block by HOLMES,RJ',
#  'Block by MARTIN,RYAN',
#  'Block by PASCHAL,ELLIOT',
#  'Block by SAX,KEVIN',
#  'Block by NEWTON,RYAN',
#  'Block by HINES,BRIAN',
#  'Block by NEWTON,RYAN',
#  'Block by FRILLING,COLE',
#  'Block by SAX,KEVIN',
#  'Block by SAX,KEVIN',
#  'Block by HOLMES,RJ',
#  'Block by PASCHAL,ELLIOT',
#  'Block by HOLMES,RJ',
#  'Block by HOLMES,RJ',
#  'Block by KUROWSKI,THOMAS',
#  'Block by EDO,LEONARDO',
#  'Block by HOLMES,RJ',
#  'Block by HOPKINS,BRYCE',
#  'Block by BHANDAL,ARRISH',
#  'Block by HOPKINS,BRYCE',
#  'Block by BHANDAL,ARRISH',
#  'Block by PASCHAL,ELLIOT',
#  'Block by HOPKINS,BRYCE',
#  'Block by WIELE,MATT',
#  'Block by PERE,BRIAN AMABILINO',
#  'Block by HOPKINS,BRYCE',
#  'Block by PASCHAL,ELLIOT',
#  'Block by WIELE,MATT',
#  'Block by STUCK,NICK',
#  'Block by MARTIN,RYAN',
#  'Block by USING,AEDAN',
#  'Block by EASTMAN,TOMMY',
#  'Block by NASSAR,SAM',
#  'Block by JUSTICE,DARRET',
#  'Block by BHANDAL,ARRISH',
#  'Block by HOPKINS,BRYCE',
#  'Block by HOPKINS,BRYCE',
#  'Block by PEEK,HAYDEN',
#  'Block by MUNSON,ZACH',
#  'Block by HOPKINS,BRYCE',
#  'Block by MUNSON,ZACH',
#  'Block by DAVET,KEVIN',
#  'Block by DAVET,KEVIN',
#  'Block by HOPKINS,BRYCE',
#  'Block by KINDSVATER,DRAKE',
#  'Block by BHANDAL,ARRISH',
#  'Block by MACK,KAMERON',
#  'Block by KINDSVATER,DRAKE',
#  'Block by KINDSVATER,DRAKE',
#  'Block by DAVET,KEVIN',
#  'Block by KINDSVATER,DRAKE',
#  'Block by HOPKINS,BRYCE']
